# %% [markdown]
# # Variational Autoencoder (VAC) training on the given dataset
# Luca attempts to train a VAC on the ITALY dataset gotten from the other notebook

# %%
# !pip install torchvision -q

# %%
# mathematics libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# VAE libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Defining the VAE

# %%
# Define the encoder and decoder networks
class VAE(nn.Module):
    def __init__(self, input_dim, hidden_dim=32, latent_dim=2):
        super(VAE, self).__init__()
        
        # Encoder
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc_mu = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)

        # Decoder
        self.fc2 = nn.Linear(latent_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, input_dim)

    def encode(self, x):
        h1 = F.relu(self.fc1(x))
        return self.fc_mu(h1), self.fc_logvar(h1)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        h = F.relu(self.fc2(z))
        return self.fc3(h) # this way we have regression, if not we do classification with: torch.sigmoid(self.fc3(h2))

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar, z # z are the latent representations of the input x 

# Loss function
def loss_function(recon_x, x, mu, logvar):
    MSE = F.mse_loss(recon_x, x, reduction='sum')
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return MSE + KLD, MSE, KLD

# %% [markdown]
# ### Loading the dataset

# %%
df = pd.read_csv('output/detrended_actuals_MSTL.csv') # loading the detrended

# ratio of renewable energy / load for a given timestamp (if < 1 renewable energy is not enough) 
ren_ratio = (df['solar_a'] + df['wind_a'] + df['hydro_a']) / df['load_a']

df['ren_ratio'] = ren_ratio

# this computes the total generation / total load
df['tot_ratio'] = df['generation_a'] / df['load_a']
df
# Out:
#        node_id time_window               window_start           t  \
# 0      IT_CALA         day  2022-01-01 06:00:00+00:00  285.435202
# 1      IT_CALA         day  2022-01-02 06:00:00+00:00  285.609332
# 2      IT_CALA         day  2022-01-03 06:00:00+00:00  284.018298
# 3      IT_CALA         day  2022-01-04 06:00:00+00:00  285.407443
# 4      IT_CALA         day  2022-01-05 06:00:00+00:00  287.234285
# ...        ...         ...                        ...         ...
# 13147  IT_SICI       night  2024-12-27 18:00:00+00:00  280.486853
# 13148  IT_SICI       night  2024-12-28 18:00:00+00:00  279.911233
# 13149  IT_SICI       night  2024-12-29 18:00:00+00:00  279.623201
# 13150  IT_SICI       night  2024-12-30 18:00:00+00:00  279.441879
# 13151  IT_SICI       night  2024-12-31 18:00:00+00:00  279.749102
#
#                  tp          solar       ws10      ws100  solar_a  wind_a  \
# 0      1.360361e-05  703479.111111  16.402459  23.951258   1241.0  6117.0
# 1      1.649062e-06  750732.444444  11.872903  17.003888   1262.0  4347.0
# 2      1.307940e-05  681079.111111  16.127072  21.415452   1161.0  6614.0
# 3      1.375492e-07  764110.222222  10.705365  14.512140   1038.0  4764.0
# 4      0.000000e+00  834547.555556  12.264336  16.324974   1175.0  3887.0
# ...             ...            ...        ...        ...      ...     ...
# 13147  2.111575e-06       0.000000   8.697010  13.051970      0.0  4992.0
# 13148  3.748162e-06       0.000000   7.361006  10.078508      0.0  2040.0
# 13149  7.854876e-08       0.000000   4.924874   5.261758      0.0   485.0
# 13150  1.811242e-07       0.000000   3.925864   3.723855      0.0   241.0
# 13151  7.962072e-07       0.000000   2.620861   3.168537      0.0   572.0
#
#        hydro_a  generation_a   load_a  ren_ratio  tot_ratio
# 0       1072.0       14355.0  11960.0   0.704849   1.200251
# 1       1056.0       10396.0   7828.0   0.851431   1.328053
# 2       1155.0       27071.0  15059.0   0.593001   1.797663
# 3       1020.0       25516.0  14880.0   0.458468   1.714785
# 4        891.0       24193.0  15506.0   0.383916   1.560235
# ...        ...           ...      ...        ...        ...
# 13147    139.0       11898.0  21347.0   0.240362   0.557362
# 13148    155.0       10290.0  20772.0   0.105671   0.495378
# 13149    114.0        9525.0  20353.0   0.029431   0.467990
# 13150    219.0       24022.0  47476.0   0.009689   0.505982
# 13151    144.0       26258.0  47853.0   0.014962   0.548722
#
# [13152 rows x 15 columns]

# %%
# taking only environmental and energy variables to train
variables_X = ['t','tp','solar','ws10','ws100','solar_a','wind_a','hydro_a']
variables_Y = ['time_window','ren_ratio']

# taking only a specific part ITALY
X = df[df['node_id'] == 'IT_NORD']
Y = X[variables_Y] # label that we try to predict

# converting Y['time_window'] into int values ( day -> 1 , night -> 0)
Y['time_window'] = [1 if x == 'day' else 0 for x in Y['time_window']]

X = X[variables_X]

# scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# convert to pytorch tensor
X_tensor = torch.tensor(X_scaled, dtype = torch.float32)
Y_tensor = torch.tensor(Y.values, dtype = torch.float32) # label that we are trying to predict

# create dataloader
dataset = TensorDataset(X_tensor, Y_tensor)
dataloader = DataLoader(dataset, batch_size = 64, shuffle = True)

input_dim = X.shape[1]
# Out:
# /tmp/ipykernel_6059/3867992842.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y['time_window'] = [1 if x == 'day' else 0 for x in Y['time_window']]

# %% [markdown]
# ### Training loop (with grid search)
# split train and test set

# %%
from torch.utils.data import random_split, DataLoader

# 80% train, 20% test
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# Grid search

# %%
from sklearn.model_selection import ParameterGrid

# Hyperparameter grid
param_grid = {
    'latent_dim': [2, 3, 4, 5, 6],
    'beta': [0.1, 1, 5],
    'lr': [1e-3, 1e-4, 1e-5]
}

# %% [markdown]
# Looking for best parameters in grid search

# %%
def evaluate_model(model, dataloader, loss_function, device):
    model.eval()
    total_loss = 0

    with torch.no_grad():
        for data, _ in dataloader:  # If your dataset has labels
            data = data.to(device)
            recon_batch, mu, logvar, _ = model(data)
            loss, _, _ = loss_function(recon_batch, data, mu, logvar)
            total_loss += loss.item()

    return total_loss / len(dataloader.dataset)

# %% [markdown]
# ### Grid search

# %%
best_loss = float('inf')
best_params = None
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for params in ParameterGrid(param_grid):
    print(f"Testing config: {params}")
    
    # Initialize model with current configuration
    model = VAE(input_dim=input_dim, latent_dim=params['latent_dim']).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=params['lr'])
    
    # Train the model (you may want to add validation loss tracking here)
    for epoch in range(30):  # or use early stopping
        model.train()
        total_loss = 0
        for batch in train_loader:
            data = batch[0].to(device)
            optimizer.zero_grad()
            recon_batch, mu, logvar, z = model(data)
            loss, _, _ = loss_function(recon_batch, data, mu, logvar)
            loss.backward()
            total_loss += loss.item()
            optimizer.step()
    
    # Evaluate the model after training (e.g., validation or test set)
    val_loss = evaluate_model(model, test_loader, loss_function, device)

    if val_loss < best_loss:
        best_loss = val_loss
        best_params = params
    print('val_loss:', val_loss)

print(f"Best hyperparameters: {best_params}")
latent_dim = best_params['latent_dim']
print(latent_dim)
# Out:
# Testing config: {'beta': 0.1, 'latent_dim': 2, 'lr': 0.001}
# val_loss: 5.521132206319405
# Testing config: {'beta': 0.1, 'latent_dim': 2, 'lr': 0.0001}
# val_loss: 7.836141807886354
# Testing config: {'beta': 0.1, 'latent_dim': 2, 'lr': 1e-05}
# val_loss: 9.104579499750853
# Testing config: {'beta': 0.1, 'latent_dim': 3, 'lr': 0.001}
# val_loss: 5.124280160543316
# Testing config: {'beta': 0.1, 'latent_dim': 3, 'lr': 0.0001}
# val_loss: 7.8138238650519645
# Testing config: {'beta': 0.1, 'latent_dim': 3, 'lr': 1e-05}
# val_loss: 8.839710557107773
# Testing config: {'beta': 0.1, 'latent_dim': 4, 'lr': 0.001}
# val_loss: 5.167257391510358
# Testing config: {'beta': 0.1, 'latent_dim': 4, 'lr': 0.0001}
# val_loss: 7.962168700059617
# Testing config: {'beta': 0.1, 'latent_dim': 4, 'lr': 1e-05}
# val_loss: 9.398136773250641
# Testing config: {'beta': 0.1, 'latent_dim': 5, 'lr': 0.001}
# val_loss: 5.240660439319654
# Testing config: {'beta': 0.1, 'latent_dim': 5, 'lr': 0.0001}
# val_loss: 7.8345759572092115
# Testing config: {'beta': 0.1, 'latent_dim': 5, 'lr': 1e-05}
# val_loss: 9.164664718176075
# Testing config: {'beta': 0.1, 'latent_dim': 6, 'lr': 0.001}
# val_loss: 5.269223363089941
# Testing config: {'beta': 0.1, 'latent_dim': 6, 'lr': 0.0001}
# val_loss: 7.715389173503346
# Testing config: {'beta': 0.1, 'latent_dim': 6, 'lr': 1e-05}
# val_loss: 8.976107864553674
# Testing config: {'beta': 1, 'latent_dim': 2, 'lr': 0.001}
# val_loss: 5.61687558115479
# Testing config: {'beta': 1, 'latent_dim': 2, 'lr': 0.0001}
# val_loss: 7.7104745226188784
# Testing config: {'beta': 1, 'latent_dim': 2, 'lr': 1e-05}
# val_loss: 9.193333862582753
# Testing config: {'beta': 1, 'latent_dim': 3, 'lr': 0.001}
# val_loss: 5.147731772316344
# Testing config: {'beta': 1, 'latent_dim': 3, 'lr': 0.0001}
# val_loss: 7.878647928085848
# Testing config: {'beta': 1, 'latent_dim': 3, 'lr': 1e-05}
# val_loss: 9.373145240314457
# Testing config: {'beta': 1, 'latent_dim': 4, 'lr': 0.001}
# val_loss: 5.191179071309083
# Testing config: {'beta': 1, 'latent_dim': 4, 'lr': 0.0001}
# val_loss: 7.744252615474623
# Testing config: {'beta': 1, 'latent_dim': 4, 'lr': 1e-05}
# val_loss: 9.202932996467469
# Testing config: {'beta': 1, 'latent_dim': 5, 'lr': 0.001}
# val_loss: 5.194877954713305
# Testing config: {'beta': 1, 'latent_dim': 5, 'lr': 0.0001}
# val_loss: 8.022285895901552
# Testing config: {'beta': 1, 'latent_dim': 5, 'lr': 1e-05}
# val_loss: 9.079189917492704
# Testing config: {'beta': 1, 'latent_dim': 6, 'lr': 0.001}
# val_loss: 5.1391438894771495
# Testing config: {'beta': 1, 'latent_dim': 6, 'lr': 0.0001}
# val_loss: 8.291665948333392
# Testing config: {'beta': 1, 'latent_dim': 6, 'lr': 1e-05}
# val_loss: 9.344144434483557
# Testing config: {'beta': 5, 'latent_dim': 2, 'lr': 0.001}
# val_loss: 5.41911701732453
# Testing config: {'beta': 5, 'latent_dim': 2, 'lr': 0.0001}
# val_loss: 7.513637742583464
# Testing config: {'beta': 5, 'latent_dim': 2, 'lr': 1e-05}
# val_loss: 9.07767474406944
# Testing config: {'beta': 5, 'latent_dim': 3, 'lr': 0.001}
# val_loss: 5.077239712169882
# Testing config: {'beta': 5, 'latent_dim': 3, 'lr': 0.0001}
# val_loss: 8.446053750422658
# Testing config: {'beta': 5, 'latent_dim': 3, 'lr': 1e-05}
# val_loss: 9.041935948956256
# Testing config: {'beta': 5, 'latent_dim': 4, 'lr': 0.001}
# val_loss: 5.208138224747295
# Testing config: {'beta': 5, 'latent_dim': 4, 'lr': 0.0001}
# val_loss: 7.924843894593536
# Testing config: {'beta': 5, 'latent_dim': 4, 'lr': 1e-05}
# val_loss: 9.298014508292995
# Testing config: {'beta': 5, 'latent_dim': 5, 'lr': 0.001}
# val_loss: 5.206243840871476
# Testing config: {'beta': 5, 'latent_dim': 5, 'lr': 0.0001}
# val_loss: 7.588367436089657
# Testing config: {'beta': 5, 'latent_dim': 5, 'lr': 1e-05}
# val_loss: 9.036163955723234
# Testing config: {'beta': 5, 'latent_dim': 6, 'lr': 0.001}
# val_loss: 5.327081632505517
# Testing config: {'beta': 5, 'latent_dim': 6, 'lr': 0.0001}
# val_loss: 8.250001529354712
# Testing config: {'beta': 5, 'latent_dim': 6, 'lr': 1e-05}
# val_loss: 9.199692988993094
# Best hyperparameters: {'beta': 5, 'latent_dim': 3, 'lr': 0.001}
# 3

# %%
# retraining on all data with best params and more epochs
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = VAE(input_dim=input_dim, latent_dim=best_params['latent_dim']).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'])

Nepoch = 100

tot_loss = np.zeros(Nepoch)
MSEs = np.zeros(Nepoch)
KLDs = np.zeros(Nepoch)
i = 0

best_loss = float('inf')
best_params = None

for epoch in range(Nepoch):
    
    model.train()
    train_loss = 0
    train_MSE = 0
    train_KLD = 0
    for batch in train_loader:
        data = batch[0].to(device) # takes X to train and ignores Y
        optimizer.zero_grad()
        recon_batch, mu, logvar, _ = model(data)
        loss, MSE, KLD = loss_function(recon_batch, data, mu, logvar)
        loss.backward()
        train_loss += loss.item()
        train_MSE += MSE
        train_KLD += KLD
        optimizer.step()
        
    tot_loss[i] = train_loss / len(train_dataset)
    MSEs[i] = train_MSE / len(train_dataset)
    KLDs[i] = train_KLD / len(train_dataset)
    print(f"Epoch {epoch+1}, Loss: {train_loss / len(train_dataset):.4f}")
    i += 1
# Out:
# Epoch 1, Loss: 8.2280
# Epoch 2, Loss: 7.7898
# Epoch 3, Loss: 7.3879
# Epoch 4, Loss: 6.9667
# Epoch 5, Loss: 6.5203
# Epoch 6, Loss: 6.1812
# Epoch 7, Loss: 5.8662
# Epoch 8, Loss: 5.7275
# Epoch 9, Loss: 5.5867
# Epoch 10, Loss: 5.4839
# Epoch 11, Loss: 5.3544
# Epoch 12, Loss: 5.2572
# Epoch 13, Loss: 5.2108
# Epoch 14, Loss: 5.1907
# Epoch 15, Loss: 5.1981
# Epoch 16, Loss: 5.1365
# Epoch 17, Loss: 5.1269
# Epoch 18, Loss: 5.0550
# Epoch 19, Loss: 5.0267
# Epoch 20, Loss: 5.0337
# Epoch 21, Loss: 5.0697
# Epoch 22, Loss: 5.0593
# Epoch 23, Loss: 5.0047
# Epoch 24, Loss: 4.9630
# Epoch 25, Loss: 5.0502
# Epoch 26, Loss: 4.9955
# Epoch 27, Loss: 5.0150
# Epoch 28, Loss: 4.9691
# Epoch 29, Loss: 5.0031
# Epoch 30, Loss: 5.0148
# Epoch 31, Loss: 4.9802
# Epoch 32, Loss: 4.9963
# Epoch 33, Loss: 4.8848
# Epoch 34, Loss: 4.8938
# Epoch 35, Loss: 4.9941
# Epoch 36, Loss: 4.9448
# Epoch 37, Loss: 4.9843
# Epoch 38, Loss: 4.9519
# Epoch 39, Loss: 4.9431
# Epoch 40, Loss: 4.9786
# Epoch 41, Loss: 5.0101
# Epoch 42, Loss: 4.9371
# Epoch 43, Loss: 4.8954
# Epoch 44, Loss: 4.9569
# Epoch 45, Loss: 4.9628
# Epoch 46, Loss: 4.9504
# Epoch 47, Loss: 4.9091
# Epoch 48, Loss: 4.9567
# Epoch 49, Loss: 4.8451
# Epoch 50, Loss: 4.8887
# Epoch 51, Loss: 4.8823
# Epoch 52, Loss: 4.8827
# Epoch 53, Loss: 4.8884
# Epoch 54, Loss: 4.8545
# Epoch 55, Loss: 4.8891
# Epoch 56, Loss: 4.8960
# Epoch 57, Loss: 4.8778
# Epoch 58, Loss: 4.8500
# Epoch 59, Loss: 4.8839
# Epoch 60, Loss: 4.8640
# Epoch 61, Loss: 4.8752
# Epoch 62, Loss: 4.9027
# Epoch 63, Loss: 4.8530
# Epoch 64, Loss: 4.8875
# Epoch 65, Loss: 4.8670
# Epoch 66, Loss: 4.8999
# Epoch 67, Loss: 4.8508
# Epoch 68, Loss: 4.8382
# Epoch 69, Loss: 4.8372
# Epoch 70, Loss: 4.8234
# Epoch 71, Loss: 4.8021
# Epoch 72, Loss: 4.8411
# Epoch 73, Loss: 4.8594
# Epoch 74, Loss: 4.8530
# Epoch 75, Loss: 4.8455
# Epoch 76, Loss: 4.8414
# Epoch 77, Loss: 4.8311
# Epoch 78, Loss: 4.8163
# Epoch 79, Loss: 4.8761
# Epoch 80, Loss: 4.8166
# Epoch 81, Loss: 4.8600
# Epoch 82, Loss: 4.8326
# Epoch 83, Loss: 4.8185
# Epoch 84, Loss: 4.7949
# Epoch 85, Loss: 4.8461
# Epoch 86, Loss: 4.8099
# Epoch 87, Loss: 4.8746
# Epoch 88, Loss: 4.7976
# Epoch 89, Loss: 4.8238
# Epoch 90, Loss: 4.7919
# Epoch 91, Loss: 4.8133
# Epoch 92, Loss: 4.8355
# Epoch 93, Loss: 4.7891
# Epoch 94, Loss: 4.8017
# Epoch 95, Loss: 4.7582
# Epoch 96, Loss: 4.8607
# Epoch 97, Loss: 4.7654
# Epoch 98, Loss: 4.7930
# Epoch 99, Loss: 4.7703
# Epoch 100, Loss: 4.8238

# %% [markdown]
# ### Tracking the losses

# %%
epochs = np.arange(1,Nepoch+1,1)

plt.figure(figsize = (6.5,5))
plt.plot(epochs, tot_loss, label = 'total loss')
plt.plot(epochs, MSEs, label = 'MSE (magnitude)')
plt.plot(epochs, KLDs, label = 'KL divergence')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %% [markdown]
# as expected KL divergence increases as the encoder regularizes, while the MSE decreases. The total loss decreases and reaches a plateau. Weird thing: i expect a MSE (magnitude) between 0 and 1 if my X are normalized (which are btw...)

# %% [markdown]
# ### Evaluating performance on test set

# %%
all_losses = []
all_labels = []
all_types = []

model.eval()
with torch.no_grad():
    for batch in test_loader:
        data = batch[0].to(device)
        recon_batch, mu, logvar, _ = model(data)

        # Reconstruction loss per sample
        losses = F.mse_loss(recon_batch, data, reduction='none').mean(dim=1)
        all_losses.append(losses.cpu())
        # Get associated renewable_coverage (second element in dataset if present)
        labels = batch[1].cpu()  # Assuming you stored renewable_coverage as label
        #print(batch[1][0][0])
        all_types.append(batch[1][0][0])
        all_labels.append(labels)

# Convert to flat arrays
all_losses = torch.cat(all_losses).numpy()
all_labels = torch.cat(all_labels).numpy()

# %% [markdown]
# ### Visualizing loss vs Renewable coverage

# %%
# getting night and day indices
all_indices = np.arange(0, len(all_labels[:,0]),1)
day_indices = np.where(all_labels[:,0] == 1)
night_indices = all_indices[~np.isin(all_indices, day_indices)]

# getting labels and losses relative to day/night
day_labels = all_labels[day_indices,:]
day_losses = all_losses[day_indices]
night_labels = all_labels[night_indices, :]
night_losses = all_losses[night_indices]
#(all_labels[:,1] < 1.0).astype(int)

# %%
plt.figure(figsize=(8, 5))
plt.scatter(day_labels[0,:,1], day_losses, color = 'orange', label = 'day data', alpha = 0.6)
plt.scatter(night_labels[:,1], night_losses, color = 'blue', label = 'night data', alpha = 0.6)
plt.axvline(1.0, color='red', linestyle='--', label='Coverage = 1')
plt.xlabel("Renewable Coverage")
plt.ylabel("Reconstruction Loss")
plt.title("Loss vs. Renewable Coverage")
plt.legend()
plt.grid(True)

true_labels = (all_labels[:,1] < 1.0).astype(int)  # 1 = under-supplied
true_labels_d = (day_labels[0,:,1] < 1.0).astype(int)  # 1 = under-supplied
true_labels_n = (night_labels[:,1] < 1.0).astype(int)  # 1 = under-supplied
print(f'percentage of under_supplied: {(sum(true_labels) / len(all_labels)*100).round(2)}%')
print(f'percentage of day_under_supplied: {(sum(true_labels_d) / len(day_labels[0])*100).round(2)}%')
print(f'percentage of night_under_supplied: {(sum(true_labels_n) / len(night_labels)*100).round(2)}%')

plt.show()
# Out:
# percentage of under_supplied: 100.0%
# percentage of day_under_supplied: 100.0%
# percentage of night_under_supplied: 100.0%

# %% [markdown]
# ### Visualizing latent space

# %%
# TSNE allows to represent multiple dimensions vector as 2D vectors (handling well the grid search on 
# hidden space params)
from sklearn.manifold import TSNE

latent_vectors = []
types = []

model.eval()  # Switch to evaluation mode
with torch.no_grad():
    for batch in test_loader:
        data = batch[0].to(device)  # Get the input features (not the labels)
        _, _, _, z = model(data)  # Get the latent representations (z)
        latent_vectors.append(z.cpu().numpy())  # Store the latent vectors on CPU

        # get day / night
        labels = batch[1][:, 0].cpu().numpy()  # Assuming "day/night" is in column 0
        types.extend(labels)    
        

latent_vectors = np.concatenate(latent_vectors, axis=0)  # Combine into one array

# Reduce the dimensionality to 2D using t-SNE
tsne = TSNE(n_components=2, random_state=42)
latent_tsne = tsne.fit_transform(latent_vectors)

types = np.array(types)
idx_day = np.where(types == 1)
idx_night = np.where(types == 0)

x_day = latent_tsne[idx_day, 0]
y_day = latent_tsne[idx_day, 1]
x_night = latent_tsne[idx_night, 0]
y_night = latent_tsne[idx_night, 1]

plt.figure(figsize=(8, 6))
plt.scatter(x_day, y_day, alpha=0.6, color = 'orange', label = 'day data')
plt.scatter(x_night, y_night, alpha=0.6, color = 'blue', label = 'night data')
plt.title("Latent Space (2D via t-SNE)")
plt.xlabel("t-SNE Dimension 1")
plt.ylabel("t-SNE Dimension 2")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Generating new data with the trained VAE

# %%
model.eval()

# Number of samples to generate
n_samples = 100
latent_dim = latent_dim  # the dimension of your latent space

with torch.no_grad():
    # Sample from standard normal distribution
    z = torch.randn(n_samples, latent_dim).to(device)

    # Decode to generate data
    generated_data = model.decode(z).cpu().numpy()

# %%
# this allows to revert the scaling
generated_df = pd.DataFrame(columns = X.columns, data = scaler.inverse_transform(generated_data))
generated_df
# Out:
#              t        tp         solar       ws10      ws100       solar_a  \
# 0   292.879608  0.000210  1.357358e+06   8.930375  10.483891  29912.257812
# 1   287.163910  0.000343  1.734855e+05   8.996428  12.599498   3591.952637
# 2   290.865570  0.000431  7.607360e+05   9.163013  11.714611  17691.837891
# 3   286.394745  0.000038  1.778659e+05   6.576294   8.831511   2439.211426
# 4   292.284729  0.000301  5.792212e+05   7.645831  10.255113  12913.978516
# ..         ...       ...           ...        ...        ...           ...
# 95  296.244873  0.000074  1.832816e+06   8.751289   9.698490  39776.980469
# 96  285.366974  0.000252  3.436865e+05  10.227144  13.857586   7681.641113
# 97  287.382446  0.000071  1.129035e+06   7.170174   8.497206  23651.460938
# 98  280.953705  0.000022  1.487292e+05   5.269991   6.231627   1895.813965
# 99  295.097809  0.000241  7.652292e+04   6.447023   9.549971    435.552216
#
#         wind_a       hydro_a
# 0   606.914124  50066.753906
# 1   814.132019  48615.851562
# 2   781.065002  58792.460938
# 3   445.351044  36328.195312
# 4   677.189941  62532.593750
# ..         ...           ...
# 95  364.202362  39039.113281
# 96  929.927917  41900.511719
# 97  433.058685  30931.750000
# 98  205.994095  22122.082031
# 99  240.401382  61855.054688
#
# [100 rows x 8 columns]

# %% [markdown]
# # Plots

# %%
df
# Out:
#        node_id time_window               window_start           t  \
# 0      IT_CALA         day  2022-01-01 06:00:00+00:00  285.435202
# 1      IT_CALA         day  2022-01-02 06:00:00+00:00  285.609332
# 2      IT_CALA         day  2022-01-03 06:00:00+00:00  284.018298
# 3      IT_CALA         day  2022-01-04 06:00:00+00:00  285.407443
# 4      IT_CALA         day  2022-01-05 06:00:00+00:00  287.234285
# ...        ...         ...                        ...         ...
# 13147  IT_SICI       night  2024-12-27 18:00:00+00:00  280.486853
# 13148  IT_SICI       night  2024-12-28 18:00:00+00:00  279.911233
# 13149  IT_SICI       night  2024-12-29 18:00:00+00:00  279.623201
# 13150  IT_SICI       night  2024-12-30 18:00:00+00:00  279.441879
# 13151  IT_SICI       night  2024-12-31 18:00:00+00:00  279.749102
#
#                  tp          solar       ws10      ws100  solar_a  wind_a  \
# 0      1.360361e-05  703479.111111  16.402459  23.951258   1241.0  6117.0
# 1      1.649062e-06  750732.444444  11.872903  17.003888   1262.0  4347.0
# 2      1.307940e-05  681079.111111  16.127072  21.415452   1161.0  6614.0
# 3      1.375492e-07  764110.222222  10.705365  14.512140   1038.0  4764.0
# 4      0.000000e+00  834547.555556  12.264336  16.324974   1175.0  3887.0
# ...             ...            ...        ...        ...      ...     ...
# 13147  2.111575e-06       0.000000   8.697010  13.051970      0.0  4992.0
# 13148  3.748162e-06       0.000000   7.361006  10.078508      0.0  2040.0
# 13149  7.854876e-08       0.000000   4.924874   5.261758      0.0   485.0
# 13150  1.811242e-07       0.000000   3.925864   3.723855      0.0   241.0
# 13151  7.962072e-07       0.000000   2.620861   3.168537      0.0   572.0
#
#        hydro_a  generation_a   load_a  ren_ratio  tot_ratio
# 0       1072.0       14355.0  11960.0   0.704849   1.200251
# 1       1056.0       10396.0   7828.0   0.851431   1.328053
# 2       1155.0       27071.0  15059.0   0.593001   1.797663
# 3       1020.0       25516.0  14880.0   0.458468   1.714785
# 4        891.0       24193.0  15506.0   0.383916   1.560235
# ...        ...           ...      ...        ...        ...
# 13147    139.0       11898.0  21347.0   0.240362   0.557362
# 13148    155.0       10290.0  20772.0   0.105671   0.495378
# 13149    114.0        9525.0  20353.0   0.029431   0.467990
# 13150    219.0       24022.0  47476.0   0.009689   0.505982
# 13151    144.0       26258.0  47853.0   0.014962   0.548722
#
# [13152 rows x 15 columns]

# %%
load = df[df['node_id'] == 'IT_NORD']
load_NORD = load['load_a']
load_NORD = load_NORD[0:int(len(load_NORD) / 24)]
date = np.arange(0,len(load) / 24 - 1,1)

print(len(date), len(load_NORD))
plt.figure(figsize = (16,10))
plt.scatter(date,load_NORD)
# Out:
# 91 91

# %%
# converting date_time into all time informations
df['year'] = pd.to_datetime(df['window_start']).year
df['month'] = pd.to_datetime(df['window_start']).month
df['day'] = pd.to_datetime(df['window_start']).day
df['hour'] = pd.to_datetime(df['window_start']).hour
df['minute'] = pd.to_datetime(df['window_start']).minute
df['second'] = pd.to_datetime(df['window_start']).second
df['day_of_week'] = pd.to_datetime(df['window_start']).day_name()

df['date'] = pd.to_datetime(df[['year','month','day']])
df['year_month'] = df['date'].dt.to_period('M').dt.to_timestamp() # creating a column for year_month (useful for grouping)

monthly_avg = df.groupby(['node_id', 'year_month'])['load'].mean().reset_index()  # averaging data for month and for state

# plot 
plt.figure(figsize=(14, 7))
sns.lineplot(data=monthly_avg, x='year_month', y='ws_100m', hue='node_id')
# custom legend (under the plot)
plt.legend(
    title='State ID',
    bbox_to_anchor=(0.5, -0.3),   # Adjust vertical position
    loc='upper center',
    ncol=9,                       # 9 columns
    frameon=False
)

plt.title('Monthly Average of wind speed at 100m (m/s) per State')
plt.xlabel('Date')
plt.ylabel('Average ws 100m (m/s)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6059/651899388.py in ?()
#       1 # converting date_time into all time informations
# ----> 2 df['year'] = pd.to_datetime(df['window_start']).year
#       3 df['month'] = pd.to_datetime(df['window_start']).month
#       4 df['day'] = pd.to_datetime(df['window_start']).day
#       5 df['hour'] = pd.to_datetime(df['window_start']).hour
#
# ~/Desktop/PoD/coding_env/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'year'
