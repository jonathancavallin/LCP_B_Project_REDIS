# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/LAB_mod_B/Project
import sys
print(sys.executable)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/LAB_mod_B/Project
# /usr/bin/python3

# %% [markdown]
# # Importing libraries

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)

# %%
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
from tqdm import tqdm
import optuna
from sklearn.model_selection import KFold
import functools

#from sklearn.model_selection import TimeSeriesSplit

# %% [markdown]
# ## Imporiting Data

# %%
# we use as temporal info the day of the year (1...365)
df_features = pd.read_csv("IT_NORD_VAE_input.csv")

features = ['timestamp', 'day_sin_t0','day_cos_t0',
           'day_sin_t1','day_cos_t1',
           'day_sin_t2','day_cos_t2',
           'day_sin_t3','day_cos_t3',
           'day_sin_t4','day_cos_t4',
           'day_sin_t5','day_cos_t5',
           'day_sin_t6','day_cos_t6',
           'day_sin_t7','day_cos_t7',
           'day_sin_t8','day_cos_t8',
           'month_sin_t0','month_cos_t0',
           'month_sin_t1','month_cos_t1',
           'month_sin_t2','month_cos_t2',
           'month_sin_t3','month_cos_t3',
           'month_sin_t4','month_cos_t4',
           'month_sin_t5','month_cos_t5',
           'month_sin_t6','month_cos_t6',
           'month_sin_t7','month_cos_t7',
           'month_sin_t8','month_cos_t8',
            'Unnamed: 0']

# in alternative one can use the following lines to keep day and month time info
'''
features = ['sin_dayofyear_t0','cos_dayofyear_t0',
            'sin_dayofyear_t1','cos_dayofyear_t1',
            'sin_dayofyear_t2','cos_dayofyear_t2',
            'sin_dayofyear_t3','cos_dayofyear_t3',
            'sin_dayofyear_t4','cos_dayofyear_t4',
            'sin_dayofyear_t5','cos_dayofyear_t5',
            'sin_dayofyear_t6','cos_dayofyear_t6',
            'sin_dayofyear_t7','cos_dayofyear_t7',
            'sin_dayofyear_t8','cos_dayofyear_t8','Unnamed: 0'] '''

df_features = df_features.drop(columns = features).iloc[:, 0:20]
df_features.shape
# Out:
# (8320, 20)

# %%
df_features.head()
# Out:
#     year_t0     2t_t0  solar_t0     tp_t0  ws_10m_t0  ws_100m_t0  hour_sin_t0  \
# 0 -1.224855 -1.266622 -0.785197 -0.540314  -0.169929    0.237315     0.249009
# 1 -1.224855 -1.324489 -0.785197 -0.540314  -0.167036    0.001132     1.183829
# 2 -1.224855 -1.363120 -0.691746 -0.543042  -0.218606   -0.093139     1.571044
# 3 -1.224855 -1.091436  0.355950 -0.543042  -0.396948   -0.530006     1.183829
# 4 -1.224855 -0.496955  0.545301 -0.543042  -0.719834   -0.962998     0.249009
#
#    hour_cos_t0  sin_dayofyear_t0  cos_dayofyear_t0  year_t1     2t_t1  \
# 0     1.890047          0.025562          1.291842 -1.22515 -1.324388
# 1     1.408519          0.025562          1.291842 -1.22515 -1.363017
# 2     0.246007          0.025562          1.291842 -1.22515 -1.091346
# 3    -0.916506          0.025562          1.291842 -1.22515 -0.496896
# 4    -1.398034          0.025562          1.291842 -1.22515 -0.515202
#
#    solar_t1     tp_t1  ws_10m_t1  ws_100m_t1  hour_sin_t1  hour_cos_t1  \
# 0 -0.785197 -0.540313  -0.166965    0.001266     1.183622     1.408711
# 1 -0.691746 -0.543041  -0.218534   -0.093002     1.570805     0.246088
# 2  0.355950 -0.543041  -0.396870   -0.529850     1.183622    -0.916535
# 3  0.545301 -0.543041  -0.719747   -0.962824     0.248877    -1.398110
# 4 -0.492313 -0.543041  -0.807978   -1.115623    -0.685868    -0.916535
#
#    sin_dayofyear_t1  cos_dayofyear_t1
# 0          0.025565          1.291842
# 1          0.025565          1.291842
# 2          0.025565          1.291842
# 3          0.025565          1.291842
# 4          0.025565          1.291842

# %% [markdown]
# Separate training and testing data

# %%
# Custom PyTorch Dataset
class TabularDataset(Dataset):                         # to use PyTorch's DataLoader
    def __init__(self, data_tensor):
        self.data = data_tensor

    def __len__(self):
        return self.data.shape[0]

    def __getitem__(self, index):
        return self.data[index], 0  # dummy label

n_samples = len(df_features)
split_idx = int(n_samples * 0.8)
INPUT_DIM = df_features.shape[1]

train_data = df_features[:split_idx]
test_data = df_features[split_idx:]

train_tensor = torch.tensor(train_data.values, dtype=torch.float32)
test_tensor = torch.tensor(test_data.values, dtype=torch.float32)

train_dataset = TabularDataset(train_tensor)
test_dataset = TabularDataset(test_tensor)

BATCH_SIZE = 128
train_loader = DataLoader(train_dataset, batch_size = BATCH_SIZE, shuffle=False)     # no shuffle
test_loader = DataLoader(test_dataset, batch_size = BATCH_SIZE, shuffle=False)

print("Input Dim:", INPUT_DIM)
print("Training Dataframe Dim:", train_loader.dataset.data.shape)
print("Testing Dataframe Dim:", test_loader.dataset.data.shape)
# Out:
# Input Dim: 20
# Training Dataframe Dim: torch.Size([6656, 20])
# Testing Dataframe Dim: torch.Size([1664, 20])

# %% [markdown]
# # Model Definition

# %%
class VariationalAutoEncoder(nn.Module):
    def __init__(self, input_dim, h_dim1, z_dim, h_dim2, activation):
        super(VariationalAutoEncoder, self).__init__()

        # encoder
        self.fc1 = nn.Linear(input_dim, h_dim1)
        self.batch1 =  nn.BatchNorm1d(h_dim1)
        self.fc_mu = nn.Linear(h_dim1, z_dim)
        self.fc_sigma = nn.Linear(h_dim1, z_dim)

        # decoder
        self.fc2 = nn.Linear(z_dim, h_dim2)
        self.batch2 = nn.BatchNorm1d(h_dim2)
        self.fc3 = nn.Linear(h_dim2, input_dim)
        self.activation = activation

    def encode(self, x):
        h1 = self.activation(self.batch1(self.fc1(x)))
        mu, sigma = self.fc_mu(h1), self.fc_sigma(h1)
        return mu, sigma

    def decode(self, z):
        h = self.activation(self.batch2(self.fc2(z)))
        return self.fc3(h)

    def forward(self, x):
        mu, sigma = self.encode(x)
        epsilon = torch.randn_like(sigma)
        z_new = mu + sigma*epsilon
        x_reconstructed = self.decode(z_new)
        return x_reconstructed, mu, sigma

# %% [markdown]
# # Training Process

# %% [markdown]
# The hyperparameters we need to specify the architecture and train the VAE are:
# * `INPUT_DIM`: the dimension of the **input** for the encoder
# * `H_DIM`: the dimension of the **hidden layers** for encoders and decoders
# * `Z_DIM`: the dimension of the **latent space**
# * `BATCH_SIZE`, `NUM_EPOCHS`, `LR_RATE`: optimization hyper-parameters

# %% [markdown]
# Definisco la funzione per il training di una fold

# %%
def train_one_fold(model, train_loader, val_loader, optimizer, loss_fn, device, num_epochs=15, z_dim=2):
  DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

  history = {
      'total_loss': [],
      'reconstruction_loss': [],
      'kl_div': [],
      'val_total_loss': [],
      'val_reconstruction_loss': [],
      'val_kl_div': []
  }
  outputs = []

  for epoch in range(num_epochs):
    epoch_loss = 0
    epoch_recon = 0
    epoch_kl = 0

    model.train()
    loop = tqdm(train_loader, desc=f"Z_DIM = {z_dim} | Epoch {epoch+1}/{num_epochs}")

    for i, (x_batch, _) in enumerate(loop):
      x_batch = x_batch.to(DEVICE)
      x_reconstructed, mu, sigma = model(x_batch)

      # Loss Function
      reconstruction_loss = loss_fn(x_reconstructed, x_batch)
      logvar = torch.log(sigma.pow(2) + 1e-8)
      kl_div = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
      loss = reconstruction_loss + kl_div

      # Backpropagation
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      loop.set_postfix(                                               # sto decidendo che info printare nella barra che vedo ad ogni epoca
          total_loss=loss.item(),
          reconstruction_loss=reconstruction_loss.item(),
          kl_div=kl_div.item())

      epoch_loss += loss.item()
      epoch_recon += reconstruction_loss.item()
      epoch_kl += kl_div.item()

      if i == 0:
        outputs.append((epoch, x_batch.clone(), x_reconstructed.clone()))

    # Compute and store averages after each epoch
    history['total_loss'].append(epoch_loss / len(train_loader.dataset))                     # appendo la loss (mediata dopo tutti i batches - quindi per un'intera epoca)
    history['reconstruction_loss'].append(epoch_recon / len(train_loader.dataset))
    history['kl_div'].append(epoch_kl / len(train_loader.dataset))

    # Validation
    model.eval()
    val_total = 0
    val_recon = 0
    val_kl = 0

    with torch.no_grad():
      for x_val, _ in val_loader:
        x_val = x_val.to(DEVICE)
        x_reconstructed, mu, sigma = model(x_val)
        loss_rec = loss_fn(x_reconstructed, x_val)
        logvar = torch.log(sigma.pow(2) + 1e-8)
        kl_div = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
        loss = loss_rec + kl_div

        val_total += loss.item()
        val_recon += loss_rec.item()
        val_kl += kl_div.item()

    history['val_total_loss'].append(val_total / len(val_loader.dataset))
    history['val_reconstruction_loss'].append(val_recon / len(val_loader.dataset))
    history['val_kl_div'].append(val_kl / len(val_loader.dataset))

  return history

# %% [markdown]
# K-Fold Loop and Hyperparameter Grid

# %%
''' k-fold cross validation classico '''
def get_activation(name):
  return {
      "relu": nn.ReLU(),
      "sigmoid": nn.Sigmoid(),
      "leaky_relu": nn.LeakyReLU()}[name]

def objective(trial, train_tensor, INPUT_DIM):
  DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  full_tensor = train_tensor
  # hyperparameters
  h_dim1 = trial.suggest_int('h_dim1', 16, 128, step=8)                                     # setta qui gli hyperparametri
  h_dim2 = trial.suggest_int('h_dim2', 16, 128, step=8)
  z_dim = trial.suggest_int('z_dim', 2, 14, step=2)
  lr = trial.suggest_loguniform('lr', 1e-4, 1e-2)
  batch_size = trial.suggest_categorical('batch_size', [16, 32, 64])

  act_name = trial.suggest_categorical("activation", ["relu", "sigmoid", "leaky_relu"])

  activation_fn = get_activation(act_name)

  kf = KFold(n_splits=5, shuffle=False)                                                     # 5 fold
  val_losses = []

  for train_idx, val_idx in kf.split(full_tensor):
    train_test = full_tensor[train_idx]
    val_test = full_tensor[val_idx]

    train_loader = DataLoader(TabularDataset(train_test), batch_size=128, shuffle=False)
    val_loader = DataLoader(TabularDataset(val_test), batch_size=128, shuffle=False)

    model = VariationalAutoEncoder(
        INPUT_DIM, h_dim1, z_dim, h_dim2,
        activation_fn).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss(reduction="sum")

    history = train_one_fold(model, train_loader, val_loader, optimizer, loss_fn, DEVICE, num_epochs=100, z_dim=z_dim)           # settare qui il numero di epochs

    val_losses.append(history['val_total_loss'][-1])

  avg_val_loss = np.mean(val_losses)
  return avg_val_loss

# %%
study = optuna.create_study(
    direction="minimize",
    pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10))

study.optimize(functools.partial(objective, train_tensor=train_tensor, INPUT_DIM=INPUT_DIM), n_trials=50, catch=(Exception,))
# Out:
# [I 2025-05-22 10:03:30,368] A new study created in memory with name: no-name-f5e818d0-cb8f-49ca-8e29-ba77828246b9
# <ipython-input-10-fbaa82e41e1b>:12: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   h_dim1 = trial.suggest_int('h_dim1', 16, 128, 8)             # added 3 new params
# <ipython-input-10-fbaa82e41e1b>:13: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   h_dim2 = trial.suggest_int('h_dim2', 16, 128, 8)
# <ipython-input-10-fbaa82e41e1b>:14: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   z_dim = trial.suggest_int('z_dim', 2, 14, 2)
# <ipython-input-10-fbaa82e41e1b>:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-4, 1e-2)
# Z_DIM = 8 | Epoch 1/50: 100%|██████████| 42/42 [00:00<00:00, 92.84it/s, kl_div=0.117, reconstruction_loss=0.375, total_loss=0.493]
# Z_DIM = 8 | Epoch 2/50: 100%|██████████| 42/42 [00:00<00:00, 126.74it/s, kl_div=0.103, reconstruction_loss=0.352, total_loss=0.455]
# Z_DIM = 8 | Epoch 3/50: 100%|██████████| 42/42 [00:00<00:00, 84.26it/s, kl_div=0.1, reconstruction_loss=0.343, total_loss=0.443]
# Z_DIM = 8 | Epoch 4/50: 100%|██████████| 42/42 [00:00<00:00, 87.97it/s, kl_div=0.0982, reconstruction_loss=0.329, total_loss=0.427]
# Z_DIM = 8 | Epoch 5/50: 100%|██████████| 42/42 [00:00<00:00, 89.89it/s, kl_div=0.0962, reconstruction_loss=0.313, total_loss=0.409]
# Z_DIM = 8 | Epoch 6/50: 100%|██████████| 42/42 [00:00<00:00, 72.89it/s, kl_div=0.0928, reconstruction_loss=0.306, total_loss=0.398]
# Z_DIM = 8 | Epoch 7/50: 100%|██████████| 42/42 [00:00<00:00, 73.49it/s, kl_div=0.0903, reconstruction_loss=0.3, total_loss=0.39]
# Z_DIM = 8 | Epoch 8/50: 100%|██████████| 42/42 [00:00<00:00, 93.20it/s, kl_div=0.0875, reconstruction_loss=0.291, total_loss=0.378]
# Z_DIM = 8 | Epoch 9/50: 100%|██████████| 42/42 [00:00<00:00, 112.38it/s, kl_div=0.0868, reconstruction_loss=0.288, total_loss=0.375]
# Z_DIM = 8 | Epoch 10/50: 100%|██████████| 42/42 [00:00<00:00, 75.14it/s, kl_div=0.0851, reconstruction_loss=0.279, total_loss=0.364]
# Z_DIM = 8 | Epoch 11/50: 100%|██████████| 42/42 [00:00<00:00, 85.07it/s, kl_div=0.0828, reconstruction_loss=0.277, total_loss=0.36]
# Z_DIM = 8 | Epoch 12/50: 100%|██████████| 42/42 [00:00<00:00, 58.07it/s, kl_div=0.0822, reconstruction_loss=0.267, total_loss=0.35]
# Z_DIM = 8 | Epoch 13/50: 100%|██████████| 42/42 [00:00<00:00, 56.70it/s, kl_div=0.0797, reconstruction_loss=0.264, total_loss=0.343]
# Z_DIM = 8 | Epoch 14/50: 100%|██████████| 42/42 [00:00<00:00, 71.51it/s, kl_div=0.0786, reconstruction_loss=0.269, total_loss=0.348]
# Z_DIM = 8 | Epoch 15/50: 100%|██████████| 42/42 [00:00<00:00, 63.39it/s, kl_div=0.0779, reconstruction_loss=0.266, total_loss=0.344]
# Z_DIM = 8 | Epoch 16/50: 100%|██████████| 42/42 [00:00<00:00, 48.58it/s, kl_div=0.0773, reconstruction_loss=0.26, total_loss=0.338]
# Z_DIM = 8 | Epoch 17/50: 100%|██████████| 42/42 [00:00<00:00, 56.89it/s, kl_div=0.0759, reconstruction_loss=0.259, total_loss=0.335]
# Z_DIM = 8 | Epoch 18/50: 100%|██████████| 42/42 [00:00<00:00, 50.83it/s, kl_div=0.0745, reconstruction_loss=0.258, total_loss=0.332]
# Z_DIM = 8 | Epoch 19/50: 100%|██████████| 42/42 [00:00<00:00, 94.27it/s, kl_div=0.0738, reconstruction_loss=0.259, total_loss=0.333]
# Z_DIM = 8 | Epoch 20/50: 100%|██████████| 42/42 [00:00<00:00, 105.02it/s, kl_div=0.0729, reconstruction_loss=0.256, total_loss=0.329]
# Z_DIM = 8 | Epoch 21/50: 100%|██████████| 42/42 [00:00<00:00, 84.81it/s, kl_div=0.072, reconstruction_loss=0.251, total_loss=0.323]
# Z_DIM = 8 | Epoch 22/50: 100%|██████████| 42/42 [00:00<00:00, 175.98it/s, kl_div=0.0709, reconstruction_loss=0.254, total_loss=0.325]
# Z_DIM = 8 | Epoch 23/50: 100%|██████████| 42/42 [00:00<00:00, 174.90it/s, kl_div=0.0725, reconstruction_loss=0.25, total_loss=0.323]
# Z_DIM = 8 | Epoch 24/50: 100%|██████████| 42/42 [00:00<00:00, 181.39it/s, kl_div=0.0712, reconstruction_loss=0.242, total_loss=0.313]
# Z_DIM = 8 | Epoch 25/50: 100%|██████████| 42/42 [00:00<00:00, 178.21it/s, kl_div=0.0702, reconstruction_loss=0.245, total_loss=0.315]
# Z_DIM = 8 | Epoch 26/50: 100%|██████████| 42/42 [00:00<00:00, 167.43it/s, kl_div=0.0703, reconstruction_loss=0.251, total_loss=0.321]
# Z_DIM = 8 | Epoch 27/50: 100%|██████████| 42/42 [00:00<00:00, 171.59it/s, kl_div=0.0714, reconstruction_loss=0.242, total_loss=0.314]
# Z_DIM = 8 | Epoch 28/50: 100%|██████████| 42/42 [00:00<00:00, 181.99it/s, kl_div=0.0703, reconstruction_loss=0.249, total_loss=0.319]
# Z_DIM = 8 | Epoch 29/50: 100%|██████████| 42/42 [00:00<00:00, 180.65it/s, kl_div=0.0691, reconstruction_loss=0.245, total_loss=0.314]
# Z_DIM = 8 | Epoch 30/50: 100%|██████████| 42/42 [00:00<00:00, 163.20it/s, kl_div=0.0674, reconstruction_loss=0.24, total_loss=0.308]
# Z_DIM = 8 | Epoch 31/50: 100%|██████████| 42/42 [00:00<00:00, 174.48it/s, kl_div=0.0682, reconstruction_loss=0.238, total_loss=0.307]
# Z_DIM = 8 | Epoch 32/50: 100%|██████████| 42/42 [00:00<00:00, 172.73it/s, kl_div=0.0679, reconstruction_loss=0.24, total_loss=0.308]
# Z_DIM = 8 | Epoch 33/50: 100%|██████████| 42/42 [00:00<00:00, 173.49it/s, kl_div=0.0677, reconstruction_loss=0.241, total_loss=0.308]
# Z_DIM = 8 | Epoch 34/50: 100%|██████████| 42/42 [00:00<00:00, 157.75it/s, kl_div=0.067, reconstruction_loss=0.242, total_loss=0.309]
# Z_DIM = 8 | Epoch 35/50: 100%|██████████| 42/42 [00:00<00:00, 182.39it/s, kl_div=0.0685, reconstruction_loss=0.247, total_loss=0.316]
# Z_DIM = 8 | Epoch 36/50: 100%|██████████| 42/42 [00:00<00:00, 191.04it/s, kl_div=0.0691, reconstruction_loss=0.236, total_loss=0.305]
# Z_DIM = 8 | Epoch 37/50: 100%|██████████| 42/42 [00:00<00:00, 180.75it/s, kl_div=0.0694, reconstruction_loss=0.237, total_loss=0.306]
# Z_DIM = 8 | Epoch 38/50: 100%|██████████| 42/42 [00:00<00:00, 152.77it/s, kl_div=0.0681, reconstruction_loss=0.242, total_loss=0.31]
# Z_DIM = 8 | Epoch 39/50: 100%|██████████| 42/42 [00:00<00:00, 175.89it/s, kl_div=0.0663, reconstruction_loss=0.241, total_loss=0.308]
# Z_DIM = 8 | Epoch 40/50: 100%|██████████| 42/42 [00:00<00:00, 190.84it/s, kl_div=0.0672, reconstruction_loss=0.244, total_loss=0.311]
# Z_DIM = 8 | Epoch 41/50: 100%|██████████| 42/42 [00:00<00:00, 177.86it/s, kl_div=0.0658, reconstruction_loss=0.233, total_loss=0.299]
# Z_DIM = 8 | Epoch 42/50: 100%|██████████| 42/42 [00:00<00:00, 161.12it/s, kl_div=0.0651, reconstruction_loss=0.241, total_loss=0.306]
# Z_DIM = 8 | Epoch 43/50: 100%|██████████| 42/42 [00:00<00:00, 183.54it/s, kl_div=0.0646, reconstruction_loss=0.239, total_loss=0.303]
# Z_DIM = 8 | Epoch 44/50: 100%|██████████| 42/42 [00:00<00:00, 160.89it/s, kl_div=0.0641, reconstruction_loss=0.246, total_loss=0.31]
# Z_DIM = 8 | Epoch 45/50: 100%|██████████| 42/42 [00:00<00:00, 174.39it/s, kl_div=0.0649, reconstruction_loss=0.242, total_loss=0.307]
# Z_DIM = 8 | Epoch 46/50: 100%|██████████| 42/42 [00:00<00:00, 159.82it/s, kl_div=0.0642, reconstruction_loss=0.236, total_loss=0.3]
# Z_DIM = 8 | Epoch 47/50: 100%|██████████| 42/42 [00:00<00:00, 171.55it/s, kl_div=0.0652, reconstruction_loss=0.237, total_loss=0.302]
# Z_DIM = 8 | Epoch 48/50: 100%|██████████| 42/42 [00:00<00:00, 182.15it/s, kl_div=0.0681, reconstruction_loss=0.234, total_loss=0.302]
# Z_DIM = 8 | Epoch 49/50: 100%|██████████| 42/42 [00:00<00:00, 182.30it/s, kl_div=0.0684, reconstruction_loss=0.243, total_loss=0.312]
# Z_DIM = 8 | Epoch 50/50: 100%|██████████| 42/42 [00:00<00:00, 156.38it/s, kl_div=0.0677, reconstruction_loss=0.24, total_loss=0.307]
# Z_DIM = 8 | Epoch 1/50: 100%|██████████| 42/42 [00:00<00:00, 173.13it/s, kl_div=0.135, reconstruction_loss=0.367, total_loss=0.502]
# Z_DIM = 8 | Epoch 2/50: 100%|██████████| 42/42 [00:00<00:00, 178.41it/s, kl_div=0.128, reconstruction_loss=0.345, total_loss=0.472]
# Z_DIM = 8 | Epoch 3/50: 100%|██████████| 42/42 [00:00<00:00, 175.04it/s, kl_div=0.12, reconstruction_loss=0.325, total_loss=0.446]
# Z_DIM = 8 | Epoch 4/50: 100%|██████████| 42/42 [00:00<00:00, 142.91it/s, kl_div=0.119, reconstruction_loss=0.312, total_loss=0.431]
# Z_DIM = 8 | Epoch 5/50: 100%|██████████| 42/42 [00:00<00:00, 133.56it/s, kl_div=0.111, reconstruction_loss=0.295, total_loss=0.406]
# Z_DIM = 8 | Epoch 6/50: 100%|██████████| 42/42 [00:00<00:00, 155.56it/s, kl_div=0.106, reconstruction_loss=0.281, total_loss=0.387]
# Z_DIM = 8 | Epoch 7/50: 100%|██████████| 42/42 [00:00<00:00, 139.03it/s, kl_div=0.102, reconstruction_loss=0.273, total_loss=0.376]
# Z_DIM = 8 | Epoch 8/50: 100%|██████████| 42/42 [00:00<00:00, 158.00it/s, kl_div=0.102, reconstruction_loss=0.272, total_loss=0.373]
# Z_DIM = 8 | Epoch 9/50: 100%|██████████| 42/42 [00:00<00:00, 122.83it/s, kl_div=0.096, reconstruction_loss=0.259, total_loss=0.355]
# Z_DIM = 8 | Epoch 10/50: 100%|██████████| 42/42 [00:00<00:00, 129.82it/s, kl_div=0.0943, reconstruction_loss=0.261, total_loss=0.355]
# Z_DIM = 8 | Epoch 11/50: 100%|██████████| 42/42 [00:00<00:00, 135.26it/s, kl_div=0.093, reconstruction_loss=0.258, total_loss=0.351]
# Z_DIM = 8 | Epoch 12/50: 100%|██████████| 42/42 [00:00<00:00, 125.50it/s, kl_div=0.0931, reconstruction_loss=0.26, total_loss=0.353]
# Z_DIM = 8 | Epoch 13/50: 100%|██████████| 42/42 [00:00<00:00, 136.45it/s, kl_div=0.0897, reconstruction_loss=0.251, total_loss=0.34]
# Z_DIM = 8 | Epoch 14/50: 100%|██████████| 42/42 [00:00<00:00, 139.49it/s, kl_div=0.0889, reconstruction_loss=0.259, total_loss=0.348]
# Z_DIM = 8 | Epoch 15/50: 100%|██████████| 42/42 [00:00<00:00, 147.67it/s, kl_div=0.0867, reconstruction_loss=0.251, total_loss=0.338]
# Z_DIM = 8 | Epoch 16/50: 100%|██████████| 42/42 [00:00<00:00, 141.10it/s, kl_div=0.0838, reconstruction_loss=0.244, total_loss=0.327]
# Z_DIM = 8 | Epoch 17/50: 100%|██████████| 42/42 [00:00<00:00, 159.45it/s, kl_div=0.0831, reconstruction_loss=0.254, total_loss=0.338]
# Z_DIM = 8 | Epoch 18/50: 100%|██████████| 42/42 [00:00<00:00, 140.71it/s, kl_div=0.0828, reconstruction_loss=0.243, total_loss=0.326]
# Z_DIM = 8 | Epoch 19/50: 100%|██████████| 42/42 [00:00<00:00, 142.59it/s, kl_div=0.0838, reconstruction_loss=0.25, total_loss=0.333]
# Z_DIM = 8 | Epoch 20/50: 100%|██████████| 42/42 [00:00<00:00, 164.80it/s, kl_div=0.082, reconstruction_loss=0.244, total_loss=0.326]
# Z_DIM = 8 | Epoch 21/50: 100%|██████████| 42/42 [00:00<00:00, 139.23it/s, kl_div=0.0815, reconstruction_loss=0.238, total_loss=0.319]
# Z_DIM = 8 | Epoch 22/50: 100%|██████████| 42/42 [00:00<00:00, 156.77it/s, kl_div=0.0844, reconstruction_loss=0.247, total_loss=0.331]
# Z_DIM = 8 | Epoch 23/50: 100%|██████████| 42/42 [00:00<00:00, 132.24it/s, kl_div=0.0833, reconstruction_loss=0.243, total_loss=0.326]
# Z_DIM = 8 | Epoch 24/50: 100%|██████████| 42/42 [00:00<00:00, 139.57it/s, kl_div=0.0807, reconstruction_loss=0.247, total_loss=0.328]
# Z_DIM = 8 | Epoch 25/50: 100%|██████████| 42/42 [00:00<00:00, 118.81it/s, kl_div=0.0808, reconstruction_loss=0.241, total_loss=0.322]
# Z_DIM = 8 | Epoch 26/50: 100%|██████████| 42/42 [00:00<00:00, 135.36it/s, kl_div=0.0795, reconstruction_loss=0.24, total_loss=0.32]
# Z_DIM = 8 | Epoch 27/50: 100%|██████████| 42/42 [00:00<00:00, 169.98it/s, kl_div=0.0793, reconstruction_loss=0.237, total_loss=0.316]
# Z_DIM = 8 | Epoch 28/50: 100%|██████████| 42/42 [00:00<00:00, 166.52it/s, kl_div=0.0807, reconstruction_loss=0.24, total_loss=0.321]
# Z_DIM = 8 | Epoch 29/50: 100%|██████████| 42/42 [00:00<00:00, 174.69it/s, kl_div=0.0793, reconstruction_loss=0.234, total_loss=0.313]
# Z_DIM = 8 | Epoch 30/50: 100%|██████████| 42/42 [00:00<00:00, 174.52it/s, kl_div=0.0802, reconstruction_loss=0.237, total_loss=0.317]
# Z_DIM = 8 | Epoch 31/50: 100%|██████████| 42/42 [00:00<00:00, 176.37it/s, kl_div=0.0784, reconstruction_loss=0.233, total_loss=0.311]
# Z_DIM = 8 | Epoch 32/50: 100%|██████████| 42/42 [00:00<00:00, 163.82it/s, kl_div=0.0772, reconstruction_loss=0.232, total_loss=0.309]
# Z_DIM = 8 | Epoch 33/50: 100%|██████████| 42/42 [00:00<00:00, 163.84it/s, kl_div=0.0767, reconstruction_loss=0.228, total_loss=0.305]
# Z_DIM = 8 | Epoch 34/50: 100%|██████████| 42/42 [00:00<00:00, 182.97it/s, kl_div=0.0772, reconstruction_loss=0.232, total_loss=0.309]
# Z_DIM = 8 | Epoch 35/50: 100%|██████████| 42/42 [00:00<00:00, 175.20it/s, kl_div=0.077, reconstruction_loss=0.232, total_loss=0.309]
# Z_DIM = 8 | Epoch 36/50: 100%|██████████| 42/42 [00:00<00:00, 159.48it/s, kl_div=0.078, reconstruction_loss=0.23, total_loss=0.308]
# Z_DIM = 8 | Epoch 37/50: 100%|██████████| 42/42 [00:00<00:00, 180.56it/s, kl_div=0.0784, reconstruction_loss=0.23, total_loss=0.308]
# Z_DIM = 8 | Epoch 38/50: 100%|██████████| 42/42 [00:00<00:00, 182.13it/s, kl_div=0.0779, reconstruction_loss=0.237, total_loss=0.315]
# Z_DIM = 8 | Epoch 39/50: 100%|██████████| 42/42 [00:00<00:00, 172.38it/s, kl_div=0.0776, reconstruction_loss=0.226, total_loss=0.303]
# Z_DIM = 8 | Epoch 40/50: 100%|██████████| 42/42 [00:00<00:00, 145.84it/s, kl_div=0.0777, reconstruction_loss=0.225, total_loss=0.303]
# Z_DIM = 8 | Epoch 41/50: 100%|██████████| 42/42 [00:00<00:00, 186.21it/s, kl_div=0.078, reconstruction_loss=0.22, total_loss=0.298]
# Z_DIM = 8 | Epoch 42/50: 100%|██████████| 42/42 [00:00<00:00, 170.57it/s, kl_div=0.0787, reconstruction_loss=0.222, total_loss=0.301]
# Z_DIM = 8 | Epoch 43/50: 100%|██████████| 42/42 [00:00<00:00, 153.13it/s, kl_div=0.0785, reconstruction_loss=0.221, total_loss=0.299]
# Z_DIM = 8 | Epoch 44/50: 100%|██████████| 42/42 [00:00<00:00, 167.73it/s, kl_div=0.0782, reconstruction_loss=0.232, total_loss=0.31]
# Z_DIM = 8 | Epoch 45/50: 100%|██████████| 42/42 [00:00<00:00, 195.42it/s, kl_div=0.0775, reconstruction_loss=0.23, total_loss=0.308]
# Z_DIM = 8 | Epoch 46/50: 100%|██████████| 42/42 [00:00<00:00, 164.47it/s, kl_div=0.0778, reconstruction_loss=0.226, total_loss=0.304]
# Z_DIM = 8 | Epoch 47/50: 100%|██████████| 42/42 [00:00<00:00, 182.30it/s, kl_div=0.0778, reconstruction_loss=0.228, total_loss=0.305]
# Z_DIM = 8 | Epoch 48/50: 100%|██████████| 42/42 [00:00<00:00, 167.31it/s, kl_div=0.0771, reconstruction_loss=0.216, total_loss=0.293]
# Z_DIM = 8 | Epoch 49/50: 100%|██████████| 42/42 [00:00<00:00, 160.27it/s, kl_div=0.0769, reconstruction_loss=0.22, total_loss=0.297]
# Z_DIM = 8 | Epoch 50/50: 100%|██████████| 42/42 [00:00<00:00, 169.35it/s, kl_div=0.0772, reconstruction_loss=0.221, total_loss=0.298]
# Z_DIM = 8 | Epoch 1/50: 100%|██████████| 42/42 [00:00<00:00, 166.72it/s, kl_div=0.151, reconstruction_loss=0.348, total_loss=0.499]
# Z_DIM = 8 | Epoch 2/50: 100%|██████████| 42/42 [00:00<00:00, 158.15it/s, kl_div=0.141, reconstruction_loss=0.335, total_loss=0.476]
# Z_DIM = 8 | Epoch 3/50: 100%|██████████| 42/42 [00:00<00:00, 172.61it/s, kl_div=0.142, reconstruction_loss=0.322, total_loss=0.464]
# Z_DIM = 8 | Epoch 4/50: 100%|██████████| 42/42 [00:00<00:00, 173.77it/s, kl_div=0.132, reconstruction_loss=0.314, total_loss=0.446]
# Z_DIM = 8 | Epoch 5/50: 100%|██████████| 42/42 [00:00<00:00, 153.88it/s, kl_div=0.126, reconstruction_loss=0.3, total_loss=0.426]
# Z_DIM = 8 | Epoch 6/50: 100%|██████████| 42/42 [00:00<00:00, 180.80it/s, kl_div=0.124, reconstruction_loss=0.293, total_loss=0.417]
# Z_DIM = 8 | Epoch 7/50: 100%|██████████| 42/42 [00:00<00:00, 165.11it/s, kl_div=0.121, reconstruction_loss=0.294, total_loss=0.415]
# Z_DIM = 8 | Epoch 8/50: 100%|██████████| 42/42 [00:00<00:00, 174.76it/s, kl_div=0.115, reconstruction_loss=0.286, total_loss=0.401]
# Z_DIM = 8 | Epoch 9/50: 100%|██████████| 42/42 [00:00<00:00, 159.59it/s, kl_div=0.114, reconstruction_loss=0.279, total_loss=0.393]
# Z_DIM = 8 | Epoch 10/50: 100%|██████████| 42/42 [00:00<00:00, 164.72it/s, kl_div=0.112, reconstruction_loss=0.278, total_loss=0.39]
# Z_DIM = 8 | Epoch 11/50: 100%|██████████| 42/42 [00:00<00:00, 169.58it/s, kl_div=0.11, reconstruction_loss=0.274, total_loss=0.385]
# Z_DIM = 8 | Epoch 12/50: 100%|██████████| 42/42 [00:00<00:00, 170.41it/s, kl_div=0.107, reconstruction_loss=0.273, total_loss=0.38]
# Z_DIM = 8 | Epoch 13/50: 100%|██████████| 42/42 [00:00<00:00, 162.82it/s, kl_div=0.106, reconstruction_loss=0.27, total_loss=0.375]
# Z_DIM = 8 | Epoch 14/50: 100%|██████████| 42/42 [00:00<00:00, 142.44it/s, kl_div=0.104, reconstruction_loss=0.273, total_loss=0.377]
# Z_DIM = 8 | Epoch 15/50: 100%|██████████| 42/42 [00:00<00:00, 157.67it/s, kl_div=0.102, reconstruction_loss=0.266, total_loss=0.367]
# Z_DIM = 8 | Epoch 16/50: 100%|██████████| 42/42 [00:00<00:00, 158.83it/s, kl_div=0.101, reconstruction_loss=0.269, total_loss=0.37]
# Z_DIM = 8 | Epoch 17/50: 100%|██████████| 42/42 [00:00<00:00, 145.47it/s, kl_div=0.1, reconstruction_loss=0.267, total_loss=0.368]
# Z_DIM = 8 | Epoch 18/50: 100%|██████████| 42/42 [00:00<00:00, 131.01it/s, kl_div=0.099, reconstruction_loss=0.269, total_loss=0.368]
# Z_DIM = 8 | Epoch 19/50: 100%|██████████| 42/42 [00:00<00:00, 139.54it/s, kl_div=0.0974, reconstruction_loss=0.264, total_loss=0.361]
# Z_DIM = 8 | Epoch 20/50: 100%|██████████| 42/42 [00:00<00:00, 154.86it/s, kl_div=0.0951, reconstruction_loss=0.263, total_loss=0.359]
# Z_DIM = 8 | Epoch 21/50: 100%|██████████| 42/42 [00:00<00:00, 148.40it/s, kl_div=0.0955, reconstruction_loss=0.263, total_loss=0.358]
# Z_DIM = 8 | Epoch 22/50: 100%|██████████| 42/42 [00:00<00:00, 153.42it/s, kl_div=0.0921, reconstruction_loss=0.264, total_loss=0.356]
# Z_DIM = 8 | Epoch 23/50: 100%|██████████| 42/42 [00:00<00:00, 156.24it/s, kl_div=0.089, reconstruction_loss=0.265, total_loss=0.354]
# Z_DIM = 8 | Epoch 24/50: 100%|██████████| 42/42 [00:00<00:00, 146.63it/s, kl_div=0.0899, reconstruction_loss=0.264, total_loss=0.354]
# Z_DIM = 8 | Epoch 25/50: 100%|██████████| 42/42 [00:00<00:00, 153.95it/s, kl_div=0.0897, reconstruction_loss=0.255, total_loss=0.345]
# Z_DIM = 8 | Epoch 26/50: 100%|██████████| 42/42 [00:00<00:00, 149.99it/s, kl_div=0.0864, reconstruction_loss=0.259, total_loss=0.345]
# Z_DIM = 8 | Epoch 27/50: 100%|██████████| 42/42 [00:00<00:00, 181.75it/s, kl_div=0.0875, reconstruction_loss=0.264, total_loss=0.352]
# Z_DIM = 8 | Epoch 28/50: 100%|██████████| 42/42 [00:00<00:00, 154.17it/s, kl_div=0.0836, reconstruction_loss=0.263, total_loss=0.347]
# Z_DIM = 8 | Epoch 29/50: 100%|██████████| 42/42 [00:00<00:00, 158.35it/s, kl_div=0.0838, reconstruction_loss=0.256, total_loss=0.34]
# Z_DIM = 8 | Epoch 30/50: 100%|██████████| 42/42 [00:00<00:00, 177.64it/s, kl_div=0.0848, reconstruction_loss=0.257, total_loss=0.341]
# Z_DIM = 8 | Epoch 31/50: 100%|██████████| 42/42 [00:00<00:00, 182.34it/s, kl_div=0.0868, reconstruction_loss=0.26, total_loss=0.347]
# Z_DIM = 8 | Epoch 32/50: 100%|██████████| 42/42 [00:00<00:00, 148.77it/s, kl_div=0.0858, reconstruction_loss=0.265, total_loss=0.351]
# Z_DIM = 8 | Epoch 33/50: 100%|██████████| 42/42 [00:00<00:00, 138.62it/s, kl_div=0.0842, reconstruction_loss=0.258, total_loss=0.342]
# Z_DIM = 8 | Epoch 34/50: 100%|██████████| 42/42 [00:00<00:00, 136.83it/s, kl_div=0.0854, reconstruction_loss=0.254, total_loss=0.34]
# Z_DIM = 8 | Epoch 35/50: 100%|██████████| 42/42 [00:00<00:00, 159.02it/s, kl_div=0.0848, reconstruction_loss=0.258, total_loss=0.342]
# Z_DIM = 8 | Epoch 36/50: 100%|██████████| 42/42 [00:00<00:00, 123.92it/s, kl_div=0.0841, reconstruction_loss=0.256, total_loss=0.341]
# Z_DIM = 8 | Epoch 37/50: 100%|██████████| 42/42 [00:00<00:00, 135.22it/s, kl_div=0.0819, reconstruction_loss=0.257, total_loss=0.339]
# Z_DIM = 8 | Epoch 38/50: 100%|██████████| 42/42 [00:00<00:00, 124.13it/s, kl_div=0.0834, reconstruction_loss=0.256, total_loss=0.339]
# Z_DIM = 8 | Epoch 39/50: 100%|██████████| 42/42 [00:00<00:00, 137.70it/s, kl_div=0.0805, reconstruction_loss=0.259, total_loss=0.339]
# Z_DIM = 8 | Epoch 40/50: 100%|██████████| 42/42 [00:00<00:00, 176.15it/s, kl_div=0.0808, reconstruction_loss=0.256, total_loss=0.336]
# Z_DIM = 8 | Epoch 41/50: 100%|██████████| 42/42 [00:00<00:00, 161.60it/s, kl_div=0.0793, reconstruction_loss=0.258, total_loss=0.337]
# Z_DIM = 8 | Epoch 42/50: 100%|██████████| 42/42 [00:00<00:00, 157.88it/s, kl_div=0.0798, reconstruction_loss=0.256, total_loss=0.336]
# Z_DIM = 8 | Epoch 43/50: 100%|██████████| 42/42 [00:00<00:00, 146.48it/s, kl_div=0.0775, reconstruction_loss=0.255, total_loss=0.333]
# Z_DIM = 8 | Epoch 44/50: 100%|██████████| 42/42 [00:00<00:00, 147.49it/s, kl_div=0.0768, reconstruction_loss=0.254, total_loss=0.331]
# Z_DIM = 8 | Epoch 45/50: 100%|██████████| 42/42 [00:00<00:00, 152.75it/s, kl_div=0.0767, reconstruction_loss=0.257, total_loss=0.334]
# Z_DIM = 8 | Epoch 46/50: 100%|██████████| 42/42 [00:00<00:00, 147.28it/s, kl_div=0.0776, reconstruction_loss=0.252, total_loss=0.33]
# Z_DIM = 8 | Epoch 47/50: 100%|██████████| 42/42 [00:00<00:00, 176.88it/s, kl_div=0.077, reconstruction_loss=0.252, total_loss=0.329]
# Z_DIM = 8 | Epoch 48/50: 100%|██████████| 42/42 [00:00<00:00, 155.92it/s, kl_div=0.0769, reconstruction_loss=0.256, total_loss=0.333]
# Z_DIM = 8 | Epoch 49/50: 100%|██████████| 42/42 [00:00<00:00, 160.09it/s, kl_div=0.0761, reconstruction_loss=0.249, total_loss=0.325]
# Z_DIM = 8 | Epoch 50/50: 100%|██████████| 42/42 [00:00<00:00, 151.58it/s, kl_div=0.0762, reconstruction_loss=0.252, total_loss=0.328]
# Z_DIM = 8 | Epoch 1/50: 100%|██████████| 42/42 [00:00<00:00, 165.95it/s, kl_div=0.119, reconstruction_loss=0.425, total_loss=0.545]
# Z_DIM = 8 | Epoch 2/50: 100%|██████████| 42/42 [00:00<00:00, 162.89it/s, kl_div=0.107, reconstruction_loss=0.411, total_loss=0.518]
# Z_DIM = 8 | Epoch 3/50: 100%|██████████| 42/42 [00:00<00:00, 169.11it/s, kl_div=0.103, reconstruction_loss=0.387, total_loss=0.49]
# Z_DIM = 8 | Epoch 4/50: 100%|██████████| 42/42 [00:00<00:00, 153.63it/s, kl_div=0.101, reconstruction_loss=0.375, total_loss=0.476]
# Z_DIM = 8 | Epoch 5/50: 100%|██████████| 42/42 [00:00<00:00, 164.59it/s, kl_div=0.0966, reconstruction_loss=0.353, total_loss=0.45]
# Z_DIM = 8 | Epoch 6/50: 100%|██████████| 42/42 [00:00<00:00, 164.06it/s, kl_div=0.0912, reconstruction_loss=0.342, total_loss=0.433]
# Z_DIM = 8 | Epoch 7/50: 100%|██████████| 42/42 [00:00<00:00, 178.24it/s, kl_div=0.0875, reconstruction_loss=0.329, total_loss=0.416]
# Z_DIM = 8 | Epoch 8/50: 100%|██████████| 42/42 [00:00<00:00, 151.44it/s, kl_div=0.0863, reconstruction_loss=0.328, total_loss=0.414]
# Z_DIM = 8 | Epoch 9/50: 100%|██████████| 42/42 [00:00<00:00, 157.22it/s, kl_div=0.0842, reconstruction_loss=0.321, total_loss=0.405]
# Z_DIM = 8 | Epoch 10/50: 100%|██████████| 42/42 [00:00<00:00, 145.99it/s, kl_div=0.0813, reconstruction_loss=0.313, total_loss=0.394]
# Z_DIM = 8 | Epoch 11/50: 100%|██████████| 42/42 [00:00<00:00, 148.00it/s, kl_div=0.0808, reconstruction_loss=0.303, total_loss=0.384]
# Z_DIM = 8 | Epoch 12/50: 100%|██████████| 42/42 [00:00<00:00, 150.49it/s, kl_div=0.0787, reconstruction_loss=0.306, total_loss=0.384]
# Z_DIM = 8 | Epoch 13/50: 100%|██████████| 42/42 [00:00<00:00, 147.92it/s, kl_div=0.0801, reconstruction_loss=0.297, total_loss=0.377]
# Z_DIM = 8 | Epoch 14/50: 100%|██████████| 42/42 [00:00<00:00, 169.04it/s, kl_div=0.0811, reconstruction_loss=0.294, total_loss=0.375]
# Z_DIM = 8 | Epoch 15/50: 100%|██████████| 42/42 [00:00<00:00, 158.10it/s, kl_div=0.0811, reconstruction_loss=0.287, total_loss=0.368]
# Z_DIM = 8 | Epoch 16/50: 100%|██████████| 42/42 [00:00<00:00, 155.97it/s, kl_div=0.0805, reconstruction_loss=0.291, total_loss=0.372]
# Z_DIM = 8 | Epoch 17/50: 100%|██████████| 42/42 [00:00<00:00, 177.20it/s, kl_div=0.0794, reconstruction_loss=0.283, total_loss=0.362]
# Z_DIM = 8 | Epoch 18/50: 100%|██████████| 42/42 [00:00<00:00, 168.13it/s, kl_div=0.0803, reconstruction_loss=0.293, total_loss=0.374]
# Z_DIM = 8 | Epoch 19/50: 100%|██████████| 42/42 [00:00<00:00, 151.48it/s, kl_div=0.0797, reconstruction_loss=0.28, total_loss=0.36]
# Z_DIM = 8 | Epoch 20/50: 100%|██████████| 42/42 [00:00<00:00, 159.35it/s, kl_div=0.0772, reconstruction_loss=0.281, total_loss=0.358]
# Z_DIM = 8 | Epoch 21/50: 100%|██████████| 42/42 [00:00<00:00, 153.50it/s, kl_div=0.077, reconstruction_loss=0.279, total_loss=0.356]
# Z_DIM = 8 | Epoch 22/50: 100%|██████████| 42/42 [00:00<00:00, 161.81it/s, kl_div=0.077, reconstruction_loss=0.284, total_loss=0.361]
# Z_DIM = 8 | Epoch 23/50: 100%|██████████| 42/42 [00:00<00:00, 159.36it/s, kl_div=0.0782, reconstruction_loss=0.274, total_loss=0.352]
# Z_DIM = 8 | Epoch 24/50: 100%|██████████| 42/42 [00:00<00:00, 142.83it/s, kl_div=0.0761, reconstruction_loss=0.282, total_loss=0.358]
# Z_DIM = 8 | Epoch 25/50: 100%|██████████| 42/42 [00:00<00:00, 133.62it/s, kl_div=0.0732, reconstruction_loss=0.275, total_loss=0.349]
# Z_DIM = 8 | Epoch 26/50: 100%|██████████| 42/42 [00:00<00:00, 126.79it/s, kl_div=0.0731, reconstruction_loss=0.273, total_loss=0.347]
# Z_DIM = 8 | Epoch 27/50: 100%|██████████| 42/42 [00:00<00:00, 126.18it/s, kl_div=0.0728, reconstruction_loss=0.273, total_loss=0.346]
# Z_DIM = 8 | Epoch 28/50: 100%|██████████| 42/42 [00:00<00:00, 146.93it/s, kl_div=0.0715, reconstruction_loss=0.28, total_loss=0.352]
# Z_DIM = 8 | Epoch 29/50: 100%|██████████| 42/42 [00:00<00:00, 163.55it/s, kl_div=0.0723, reconstruction_loss=0.27, total_loss=0.342]
# Z_DIM = 8 | Epoch 30/50: 100%|██████████| 42/42 [00:00<00:00, 142.21it/s, kl_div=0.0714, reconstruction_loss=0.27, total_loss=0.341]
# Z_DIM = 8 | Epoch 31/50: 100%|██████████| 42/42 [00:00<00:00, 161.46it/s, kl_div=0.0706, reconstruction_loss=0.276, total_loss=0.347]
# Z_DIM = 8 | Epoch 32/50: 100%|██████████| 42/42 [00:00<00:00, 126.33it/s, kl_div=0.0708, reconstruction_loss=0.263, total_loss=0.333]
# Z_DIM = 8 | Epoch 33/50: 100%|██████████| 42/42 [00:00<00:00, 140.10it/s, kl_div=0.0697, reconstruction_loss=0.277, total_loss=0.347]
# Z_DIM = 8 | Epoch 34/50: 100%|██████████| 42/42 [00:00<00:00, 138.13it/s, kl_div=0.0713, reconstruction_loss=0.264, total_loss=0.335]
# Z_DIM = 8 | Epoch 35/50: 100%|██████████| 42/42 [00:00<00:00, 125.40it/s, kl_div=0.0693, reconstruction_loss=0.267, total_loss=0.336]
# Z_DIM = 8 | Epoch 36/50: 100%|██████████| 42/42 [00:00<00:00, 133.47it/s, kl_div=0.0678, reconstruction_loss=0.269, total_loss=0.337]
# Z_DIM = 8 | Epoch 37/50: 100%|██████████| 42/42 [00:00<00:00, 149.40it/s, kl_div=0.0697, reconstruction_loss=0.266, total_loss=0.335]
# Z_DIM = 8 | Epoch 38/50: 100%|██████████| 42/42 [00:00<00:00, 134.02it/s, kl_div=0.0697, reconstruction_loss=0.268, total_loss=0.338]
# Z_DIM = 8 | Epoch 39/50: 100%|██████████| 42/42 [00:00<00:00, 144.82it/s, kl_div=0.0697, reconstruction_loss=0.27, total_loss=0.34]
# Z_DIM = 8 | Epoch 40/50: 100%|██████████| 42/42 [00:00<00:00, 138.09it/s, kl_div=0.0711, reconstruction_loss=0.263, total_loss=0.334]
# Z_DIM = 8 | Epoch 41/50: 100%|██████████| 42/42 [00:00<00:00, 156.65it/s, kl_div=0.0704, reconstruction_loss=0.266, total_loss=0.337]
# Z_DIM = 8 | Epoch 42/50: 100%|██████████| 42/42 [00:00<00:00, 144.71it/s, kl_div=0.0694, reconstruction_loss=0.259, total_loss=0.329]
# Z_DIM = 8 | Epoch 43/50: 100%|██████████| 42/42 [00:00<00:00, 147.46it/s, kl_div=0.0694, reconstruction_loss=0.265, total_loss=0.335]
# Z_DIM = 8 | Epoch 44/50: 100%|██████████| 42/42 [00:00<00:00, 128.00it/s, kl_div=0.0691, reconstruction_loss=0.262, total_loss=0.331]
# Z_DIM = 8 | Epoch 45/50: 100%|██████████| 42/42 [00:00<00:00, 137.81it/s, kl_div=0.0688, reconstruction_loss=0.262, total_loss=0.331]
# Z_DIM = 8 | Epoch 46/50: 100%|██████████| 42/42 [00:00<00:00, 132.94it/s, kl_div=0.0673, reconstruction_loss=0.258, total_loss=0.325]
# Z_DIM = 8 | Epoch 47/50: 100%|██████████| 42/42 [00:00<00:00, 157.98it/s, kl_div=0.068, reconstruction_loss=0.262, total_loss=0.33]
# Z_DIM = 8 | Epoch 48/50: 100%|██████████| 42/42 [00:00<00:00, 138.90it/s, kl_div=0.0688, reconstruction_loss=0.265, total_loss=0.334]
# Z_DIM = 8 | Epoch 49/50: 100%|██████████| 42/42 [00:00<00:00, 156.46it/s, kl_div=0.0695, reconstruction_loss=0.262, total_loss=0.331]
# Z_DIM = 8 | Epoch 50/50: 100%|██████████| 42/42 [00:00<00:00, 152.07it/s, kl_div=0.0675, reconstruction_loss=0.262, total_loss=0.329]
# Z_DIM = 8 | Epoch 1/50: 100%|██████████| 42/42 [00:00<00:00, 160.05it/s, kl_div=0.137, reconstruction_loss=0.327, total_loss=0.464]
# Z_DIM = 8 | Epoch 2/50: 100%|██████████| 42/42 [00:00<00:00, 168.53it/s, kl_div=0.13, reconstruction_loss=0.309, total_loss=0.439]
# Z_DIM = 8 | Epoch 3/50: 100%|██████████| 42/42 [00:00<00:00, 169.47it/s, kl_div=0.123, reconstruction_loss=0.291, total_loss=0.414]
# Z_DIM = 8 | Epoch 4/50: 100%|██████████| 42/42 [00:00<00:00, 151.82it/s, kl_div=0.118, reconstruction_loss=0.281, total_loss=0.399]
# Z_DIM = 8 | Epoch 5/50: 100%|██████████| 42/42 [00:00<00:00, 148.54it/s, kl_div=0.115, reconstruction_loss=0.265, total_loss=0.38]
# Z_DIM = 8 | Epoch 6/50: 100%|██████████| 42/42 [00:00<00:00, 174.64it/s, kl_div=0.117, reconstruction_loss=0.258, total_loss=0.375]
# Z_DIM = 8 | Epoch 7/50: 100%|██████████| 42/42 [00:00<00:00, 175.86it/s, kl_div=0.114, reconstruction_loss=0.249, total_loss=0.363]
# Z_DIM = 8 | Epoch 8/50: 100%|██████████| 42/42 [00:00<00:00, 153.29it/s, kl_div=0.112, reconstruction_loss=0.248, total_loss=0.36]
# Z_DIM = 8 | Epoch 9/50: 100%|██████████| 42/42 [00:00<00:00, 159.47it/s, kl_div=0.115, reconstruction_loss=0.248, total_loss=0.363]
# Z_DIM = 8 | Epoch 10/50: 100%|██████████| 42/42 [00:00<00:00, 177.71it/s, kl_div=0.116, reconstruction_loss=0.237, total_loss=0.353]
# Z_DIM = 8 | Epoch 11/50: 100%|██████████| 42/42 [00:00<00:00, 174.12it/s, kl_div=0.112, reconstruction_loss=0.238, total_loss=0.35]
# Z_DIM = 8 | Epoch 12/50: 100%|██████████| 42/42 [00:00<00:00, 148.30it/s, kl_div=0.11, reconstruction_loss=0.237, total_loss=0.347]
# Z_DIM = 8 | Epoch 13/50: 100%|██████████| 42/42 [00:00<00:00, 171.50it/s, kl_div=0.106, reconstruction_loss=0.229, total_loss=0.336]
# Z_DIM = 8 | Epoch 14/50: 100%|██████████| 42/42 [00:00<00:00, 172.34it/s, kl_div=0.106, reconstruction_loss=0.228, total_loss=0.334]
# Z_DIM = 8 | Epoch 15/50: 100%|██████████| 42/42 [00:00<00:00, 163.79it/s, kl_div=0.102, reconstruction_loss=0.228, total_loss=0.329]
# Z_DIM = 8 | Epoch 16/50: 100%|██████████| 42/42 [00:00<00:00, 154.35it/s, kl_div=0.1, reconstruction_loss=0.229, total_loss=0.329]
# Z_DIM = 8 | Epoch 17/50: 100%|██████████| 42/42 [00:00<00:00, 180.97it/s, kl_div=0.0987, reconstruction_loss=0.23, total_loss=0.328]
# Z_DIM = 8 | Epoch 18/50: 100%|██████████| 42/42 [00:00<00:00, 171.95it/s, kl_div=0.0975, reconstruction_loss=0.23, total_loss=0.327]
# Z_DIM = 8 | Epoch 19/50: 100%|██████████| 42/42 [00:00<00:00, 171.39it/s, kl_div=0.0983, reconstruction_loss=0.229, total_loss=0.327]
# Z_DIM = 8 | Epoch 20/50: 100%|██████████| 42/42 [00:00<00:00, 155.35it/s, kl_div=0.096, reconstruction_loss=0.228, total_loss=0.324]
# Z_DIM = 8 | Epoch 21/50: 100%|██████████| 42/42 [00:00<00:00, 172.95it/s, kl_div=0.0979, reconstruction_loss=0.227, total_loss=0.325]
# Z_DIM = 8 | Epoch 22/50: 100%|██████████| 42/42 [00:00<00:00, 170.39it/s, kl_div=0.0977, reconstruction_loss=0.225, total_loss=0.323]
# Z_DIM = 8 | Epoch 23/50: 100%|██████████| 42/42 [00:00<00:00, 175.10it/s, kl_div=0.0984, reconstruction_loss=0.227, total_loss=0.325]
# Z_DIM = 8 | Epoch 24/50: 100%|██████████| 42/42 [00:00<00:00, 158.27it/s, kl_div=0.0957, reconstruction_loss=0.221, total_loss=0.317]
# Z_DIM = 8 | Epoch 25/50: 100%|██████████| 42/42 [00:00<00:00, 184.33it/s, kl_div=0.0951, reconstruction_loss=0.221, total_loss=0.317]
# Z_DIM = 8 | Epoch 26/50: 100%|██████████| 42/42 [00:00<00:00, 175.60it/s, kl_div=0.095, reconstruction_loss=0.219, total_loss=0.314]
# Z_DIM = 8 | Epoch 27/50: 100%|██████████| 42/42 [00:00<00:00, 173.36it/s, kl_div=0.093, reconstruction_loss=0.221, total_loss=0.314]
# Z_DIM = 8 | Epoch 28/50: 100%|██████████| 42/42 [00:00<00:00, 162.63it/s, kl_div=0.0932, reconstruction_loss=0.214, total_loss=0.307]
# Z_DIM = 8 | Epoch 29/50: 100%|██████████| 42/42 [00:00<00:00, 181.75it/s, kl_div=0.0935, reconstruction_loss=0.215, total_loss=0.309]
# Z_DIM = 8 | Epoch 30/50: 100%|██████████| 42/42 [00:00<00:00, 140.69it/s, kl_div=0.092, reconstruction_loss=0.218, total_loss=0.31]
# Z_DIM = 8 | Epoch 31/50: 100%|██████████| 42/42 [00:00<00:00, 161.13it/s, kl_div=0.092, reconstruction_loss=0.214, total_loss=0.306]
# Z_DIM = 8 | Epoch 32/50: 100%|██████████| 42/42 [00:00<00:00, 164.81it/s, kl_div=0.0903, reconstruction_loss=0.219, total_loss=0.309]
# Z_DIM = 8 | Epoch 33/50: 100%|██████████| 42/42 [00:00<00:00, 161.73it/s, kl_div=0.0912, reconstruction_loss=0.211, total_loss=0.302]
# Z_DIM = 8 | Epoch 34/50: 100%|██████████| 42/42 [00:00<00:00, 123.59it/s, kl_div=0.0873, reconstruction_loss=0.217, total_loss=0.304]
# Z_DIM = 8 | Epoch 35/50: 100%|██████████| 42/42 [00:00<00:00, 133.67it/s, kl_div=0.0865, reconstruction_loss=0.212, total_loss=0.299]
# Z_DIM = 8 | Epoch 36/50: 100%|██████████| 42/42 [00:00<00:00, 166.67it/s, kl_div=0.0867, reconstruction_loss=0.211, total_loss=0.298]
# Z_DIM = 8 | Epoch 37/50: 100%|██████████| 42/42 [00:00<00:00, 166.85it/s, kl_div=0.0851, reconstruction_loss=0.213, total_loss=0.298]
# Z_DIM = 8 | Epoch 38/50: 100%|██████████| 42/42 [00:00<00:00, 132.04it/s, kl_div=0.085, reconstruction_loss=0.207, total_loss=0.292]
# Z_DIM = 8 | Epoch 39/50: 100%|██████████| 42/42 [00:00<00:00, 152.85it/s, kl_div=0.0847, reconstruction_loss=0.211, total_loss=0.296]
# Z_DIM = 8 | Epoch 40/50: 100%|██████████| 42/42 [00:00<00:00, 127.52it/s, kl_div=0.0852, reconstruction_loss=0.204, total_loss=0.289]
# Z_DIM = 8 | Epoch 41/50: 100%|██████████| 42/42 [00:00<00:00, 121.54it/s, kl_div=0.0858, reconstruction_loss=0.206, total_loss=0.292]
# Z_DIM = 8 | Epoch 42/50: 100%|██████████| 42/42 [00:00<00:00, 135.02it/s, kl_div=0.0842, reconstruction_loss=0.213, total_loss=0.297]
# Z_DIM = 8 | Epoch 43/50: 100%|██████████| 42/42 [00:00<00:00, 138.00it/s, kl_div=0.0836, reconstruction_loss=0.207, total_loss=0.29]
# Z_DIM = 8 | Epoch 44/50: 100%|██████████| 42/42 [00:00<00:00, 148.56it/s, kl_div=0.0862, reconstruction_loss=0.209, total_loss=0.295]
# Z_DIM = 8 | Epoch 45/50: 100%|██████████| 42/42 [00:00<00:00, 43.53it/s, kl_div=0.0841, reconstruction_loss=0.213, total_loss=0.297]
# Z_DIM = 8 | Epoch 46/50: 100%|██████████| 42/42 [00:00<00:00, 158.14it/s, kl_div=0.0835, reconstruction_loss=0.206, total_loss=0.29]
# Z_DIM = 8 | Epoch 47/50: 100%|██████████| 42/42 [00:01<00:00, 39.54it/s, kl_div=0.0842, reconstruction_loss=0.204, total_loss=0.288]
# Z_DIM = 8 | Epoch 48/50: 100%|██████████| 42/42 [00:00<00:00, 129.97it/s, kl_div=0.0824, reconstruction_loss=0.205, total_loss=0.288]
# Z_DIM = 8 | Epoch 49/50: 100%|██████████| 42/42 [00:00<00:00, 44.46it/s, kl_div=0.0819, reconstruction_loss=0.21, total_loss=0.292]
# Z_DIM = 8 | Epoch 50/50: 100%|██████████| 42/42 [00:00<00:00, 134.04it/s, kl_div=0.0824, reconstruction_loss=0.2, total_loss=0.283]
# [I 2025-05-22 10:04:54,462] Trial 0 finished with value: 21.496215350826127 and parameters: {'h_dim1': 72, 'h_dim2': 40, 'z_dim': 8, 'lr': 0.00021811263356055608, 'batch_size': 32, 'activation': 'relu'}. Best is trial 0 with value: 21.496215350826127.
# <ipython-input-10-fbaa82e41e1b>:12: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   h_dim1 = trial.suggest_int('h_dim1', 16, 128, 8)             # added 3 new params
# <ipython-input-10-fbaa82e41e1b>:13: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   h_dim2 = trial.suggest_int('h_dim2', 16, 128, 8)
# <ipython-input-10-fbaa82e41e1b>:14: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   z_dim = trial.suggest_int('z_dim', 2, 14, 2)
# <ipython-input-10-fbaa82e41e1b>:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-4, 1e-2)
# Z_DIM = 6 | Epoch 1/50: 100%|██████████| 42/42 [00:00<00:00, 153.80it/s, kl_div=0.0995, reconstruction_loss=0.389, total_loss=0.489]
# Z_DIM = 6 | Epoch 2/50: 100%|██████████| 42/42 [00:00<00:00, 149.13it/s, kl_div=0.095, reconstruction_loss=0.368, total_loss=0.463]
# Z_DIM = 6 | Epoch 3/50: 100%|██████████| 42/42 [00:00<00:00, 119.85it/s, kl_div=0.0888, reconstruction_loss=0.354, total_loss=0.442]
# Z_DIM = 6 | Epoch 4/50: 100%|██████████| 42/42 [00:00<00:00, 136.28it/s, kl_div=0.084, reconstruction_loss=0.343, total_loss=0.427]
# Z_DIM = 6 | Epoch 5/50: 100%|██████████| 42/42 [00:00<00:00, 161.00it/s, kl_div=0.0808, reconstruction_loss=0.327, total_loss=0.408]
# Z_DIM = 6 | Epoch 6/50: 100%|██████████| 42/42 [00:00<00:00, 164.71it/s, kl_div=0.0797, reconstruction_loss=0.322, total_loss=0.402]
# Z_DIM = 6 | Epoch 7/50: 100%|██████████| 42/42 [00:00<00:00, 156.54it/s, kl_div=0.0754, reconstruction_loss=0.317, total_loss=0.392]
# Z_DIM = 6 | Epoch 8/50: 100%|██████████| 42/42 [00:00<00:00, 163.00it/s, kl_div=0.0731, reconstruction_loss=0.313, total_loss=0.386]
# Z_DIM = 6 | Epoch 9/50: 100%|██████████| 42/42 [00:00<00:00, 138.94it/s, kl_div=0.0702, reconstruction_loss=0.308, total_loss=0.379]
# Z_DIM = 6 | Epoch 10/50: 100%|██████████| 42/42 [00:00<00:00, 150.48it/s, kl_div=0.0691, reconstruction_loss=0.295, total_loss=0.364]
# Z_DIM = 6 | Epoch 11/50: 100%|██████████| 42/42 [00:00<00:00, 154.68it/s, kl_div=0.0677, reconstruction_loss=0.289, total_loss=0.356]
# Z_DIM = 6 | Epoch 12/50: 100%|██████████| 42/42 [00:00<00:00, 151.86it/s, kl_div=0.0667, reconstruction_loss=0.292, total_loss=0.359]
# Z_DIM = 6 | Epoch 13/50: 100%|██████████| 42/42 [00:00<00:00, 152.13it/s, kl_div=0.0645, reconstruction_loss=0.292, total_loss=0.357]
# Z_DIM = 6 | Epoch 14/50: 100%|██████████| 42/42 [00:00<00:00, 134.80it/s, kl_div=0.064, reconstruction_loss=0.277, total_loss=0.341]
# Z_DIM = 6 | Epoch 15/50: 100%|██████████| 42/42 [00:00<00:00, 139.87it/s, kl_div=0.0645, reconstruction_loss=0.264, total_loss=0.328]
# Z_DIM = 6 | Epoch 16/50: 100%|██████████| 42/42 [00:00<00:00, 151.01it/s, kl_div=0.0636, reconstruction_loss=0.261, total_loss=0.325]
# Z_DIM = 6 | Epoch 17/50: 100%|██████████| 42/42 [00:00<00:00, 139.68it/s, kl_div=0.0628, reconstruction_loss=0.263, total_loss=0.326]
# Z_DIM = 6 | Epoch 18/50: 100%|██████████| 42/42 [00:00<00:00, 151.94it/s, kl_div=0.0633, reconstruction_loss=0.263, total_loss=0.326]
# Z_DIM = 6 | Epoch 19/50: 100%|██████████| 42/42 [00:00<00:00, 129.12it/s, kl_div=0.063, reconstruction_loss=0.263, total_loss=0.326]
# Z_DIM = 6 | Epoch 20/50: 100%|██████████| 42/42 [00:00<00:00, 150.09it/s, kl_div=0.0626, reconstruction_loss=0.26, total_loss=0.322]
# Z_DIM = 6 | Epoch 21/50: 100%|██████████| 42/42 [00:00<00:00, 159.04it/s, kl_div=0.0625, reconstruction_loss=0.261, total_loss=0.323]
# Z_DIM = 6 | Epoch 22/50: 100%|██████████| 42/42 [00:00<00:00, 144.03it/s, kl_div=0.063, reconstruction_loss=0.25, total_loss=0.313]
# Z_DIM = 6 | Epoch 23/50: 100%|██████████| 42/42 [00:00<00:00, 157.78it/s, kl_div=0.0625, reconstruction_loss=0.249, total_loss=0.311]
# Z_DIM = 6 | Epoch 24/50: 100%|██████████| 42/42 [00:00<00:00, 147.95it/s, kl_div=0.0624, reconstruction_loss=0.256, total_loss=0.319]
# Z_DIM = 6 | Epoch 25/50: 100%|██████████| 42/42 [00:00<00:00, 142.12it/s, kl_div=0.0621, reconstruction_loss=0.247, total_loss=0.309]
# Z_DIM = 6 | Epoch 26/50: 100%|██████████| 42/42 [00:00<00:00, 132.38it/s, kl_div=0.0618, reconstruction_loss=0.246, total_loss=0.308]
# Z_DIM = 6 | Epoch 27/50: 100%|██████████| 42/42 [00:00<00:00, 153.44it/s, kl_div=0.0618, reconstruction_loss=0.246, total_loss=0.308]
# Z_DIM = 6 | Epoch 28/50: 100%|██████████| 42/42 [00:00<00:00, 148.67it/s, kl_div=0.062, reconstruction_loss=0.248, total_loss=0.31]
# Z_DIM = 6 | Epoch 29/50: 100%|██████████| 42/42 [00:00<00:00, 162.59it/s, kl_div=0.0608, reconstruction_loss=0.242, total_loss=0.303]
# Z_DIM = 6 | Epoch 30/50: 100%|██████████| 42/42 [00:00<00:00, 135.74it/s, kl_div=0.0608, reconstruction_loss=0.252, total_loss=0.313]
# Z_DIM = 6 | Epoch 31/50: 100%|██████████| 42/42 [00:00<00:00, 136.45it/s, kl_div=0.0604, reconstruction_loss=0.241, total_loss=0.301]
# Z_DIM = 6 | Epoch 32/50: 100%|██████████| 42/42 [00:00<00:00, 139.15it/s, kl_div=0.0608, reconstruction_loss=0.241, total_loss=0.302]
# Z_DIM = 6 | Epoch 33/50: 100%|██████████| 42/42 [00:00<00:00, 141.61it/s, kl_div=0.0609, reconstruction_loss=0.248, total_loss=0.309]
# Z_DIM = 6 | Epoch 34/50: 100%|██████████| 42/42 [00:00<00:00, 170.58it/s, kl_div=0.0613, reconstruction_loss=0.24, total_loss=0.301]
# Z_DIM = 6 | Epoch 35/50: 100%|██████████| 42/42 [00:00<00:00, 148.42it/s, kl_div=0.0612, reconstruction_loss=0.237, total_loss=0.298]
# Z_DIM = 6 | Epoch 36/50: 100%|██████████| 42/42 [00:00<00:00, 149.24it/s, kl_div=0.0593, reconstruction_loss=0.235, total_loss=0.294]
# Z_DIM = 6 | Epoch 37/50: 100%|██████████| 42/42 [00:00<00:00, 158.92it/s, kl_div=0.0587, reconstruction_loss=0.238, total_loss=0.297]
# Z_DIM = 6 | Epoch 38/50: 100%|██████████| 42/42 [00:00<00:00, 158.71it/s, kl_div=0.0598, reconstruction_loss=0.236, total_loss=0.296]
# Z_DIM = 6 | Epoch 39/50: 100%|██████████| 42/42 [00:00<00:00, 112.32it/s, kl_div=0.0592, reconstruction_loss=0.234, total_loss=0.294]
# Z_DIM = 6 | Epoch 40/50: 100%|██████████| 42/42 [00:00<00:00, 61.06it/s, kl_div=0.0585, reconstruction_loss=0.238, total_loss=0.296]
# Z_DIM = 6 | Epoch 41/50: 100%|██████████| 42/42 [00:00<00:00, 46.38it/s, kl_div=0.0581, reconstruction_loss=0.235, total_loss=0.293]
# Z_DIM = 6 | Epoch 42/50: 100%|██████████| 42/42 [00:00<00:00, 46.19it/s, kl_div=0.0587, reconstruction_loss=0.231, total_loss=0.29]
# Z_DIM = 6 | Epoch 43/50: 100%|██████████| 42/42 [00:00<00:00, 55.85it/s, kl_div=0.0586, reconstruction_loss=0.234, total_loss=0.293]
# Z_DIM = 6 | Epoch 44/50: 100%|██████████| 42/42 [00:00<00:00, 44.71it/s, kl_div=0.0587, reconstruction_loss=0.231, total_loss=0.29]
# Z_DIM = 6 | Epoch 45/50: 100%|██████████| 42/42 [00:01<00:00, 39.19it/s, kl_div=0.0584, reconstruction_loss=0.226, total_loss=0.284]
# Z_DIM = 6 | Epoch 46/50: 100%|██████████| 42/42 [00:01<00:00, 41.39it/s, kl_div=0.0575, reconstruction_loss=0.237, total_loss=0.294]
# Z_DIM = 6 | Epoch 47/50: 100%|██████████| 42/42 [00:00<00:00, 72.45it/s, kl_div=0.0572, reconstruction_loss=0.23, total_loss=0.287]
# Z_DIM = 6 | Epoch 48/50: 100%|██████████| 42/42 [00:00<00:00, 58.22it/s, kl_div=0.057, reconstruction_loss=0.225, total_loss=0.282]
# Z_DIM = 6 | Epoch 49/50: 100%|██████████| 42/42 [00:00<00:00, 90.72it/s, kl_div=0.0576, reconstruction_loss=0.238, total_loss=0.295]
# Z_DIM = 6 | Epoch 50/50: 100%|██████████| 42/42 [00:00<00:00, 50.94it/s, kl_div=0.0568, reconstruction_loss=0.238, total_loss=0.294]
# Z_DIM = 6 | Epoch 1/50: 100%|██████████| 42/42 [00:00<00:00, 61.66it/s, kl_div=0.0834, reconstruction_loss=0.421, total_loss=0.504]
# Z_DIM = 6 | Epoch 2/50: 100%|██████████| 42/42 [00:00<00:00, 146.56it/s, kl_div=0.0775, reconstruction_loss=0.386, total_loss=0.464]
# Z_DIM = 6 | Epoch 3/50: 100%|██████████| 42/42 [00:00<00:00, 167.03it/s, kl_div=0.076, reconstruction_loss=0.367, total_loss=0.443]
# Z_DIM = 6 | Epoch 4/50: 100%|██████████| 42/42 [00:00<00:00, 156.83it/s, kl_div=0.0731, reconstruction_loss=0.348, total_loss=0.421]
# Z_DIM = 6 | Epoch 5/50: 100%|██████████| 42/42 [00:00<00:00, 148.30it/s, kl_div=0.0695, reconstruction_loss=0.332, total_loss=0.401]
# Z_DIM = 6 | Epoch 6/50: 100%|██████████| 42/42 [00:00<00:00, 141.19it/s, kl_div=0.0681, reconstruction_loss=0.317, total_loss=0.385]
# Z_DIM = 6 | Epoch 7/50: 100%|██████████| 42/42 [00:00<00:00, 150.15it/s, kl_div=0.0683, reconstruction_loss=0.306, total_loss=0.374]
# Z_DIM = 6 | Epoch 8/50: 100%|██████████| 42/42 [00:00<00:00, 153.04it/s, kl_div=0.0681, reconstruction_loss=0.296, total_loss=0.364]
# Z_DIM = 6 | Epoch 9/50: 100%|██████████| 42/42 [00:00<00:00, 145.04it/s, kl_div=0.0667, reconstruction_loss=0.293, total_loss=0.359]
# Z_DIM = 6 | Epoch 10/50: 100%|██████████| 42/42 [00:00<00:00, 148.83it/s, kl_div=0.0664, reconstruction_loss=0.289, total_loss=0.355]
# Z_DIM = 6 | Epoch 11/50: 100%|██████████| 42/42 [00:00<00:00, 152.26it/s, kl_div=0.0661, reconstruction_loss=0.274, total_loss=0.34]
# Z_DIM = 6 | Epoch 12/50: 100%|██████████| 42/42 [00:00<00:00, 145.55it/s, kl_div=0.0644, reconstruction_loss=0.277, total_loss=0.341]
# Z_DIM = 6 | Epoch 13/50: 100%|██████████| 42/42 [00:00<00:00, 138.73it/s, kl_div=0.0646, reconstruction_loss=0.275, total_loss=0.34]
# Z_DIM = 6 | Epoch 14/50: 100%|██████████| 42/42 [00:00<00:00, 160.42it/s, kl_div=0.0646, reconstruction_loss=0.264, total_loss=0.329]
# Z_DIM = 6 | Epoch 15/50: 100%|██████████| 42/42 [00:00<00:00, 153.28it/s, kl_div=0.0642, reconstruction_loss=0.266, total_loss=0.33]
# Z_DIM = 6 | Epoch 16/50: 100%|██████████| 42/42 [00:00<00:00, 147.68it/s, kl_div=0.0632, reconstruction_loss=0.258, total_loss=0.321]
# Z_DIM = 6 | Epoch 17/50: 100%|██████████| 42/42 [00:00<00:00, 141.96it/s, kl_div=0.0628, reconstruction_loss=0.264, total_loss=0.326]
# Z_DIM = 6 | Epoch 18/50: 100%|██████████| 42/42 [00:00<00:00, 169.31it/s, kl_div=0.0644, reconstruction_loss=0.259, total_loss=0.323]
# Z_DIM = 6 | Epoch 19/50: 100%|██████████| 42/42 [00:00<00:00, 133.11it/s, kl_div=0.0644, reconstruction_loss=0.272, total_loss=0.336]
# Z_DIM = 6 | Epoch 20/50: 100%|██████████| 42/42 [00:00<00:00, 137.35it/s, kl_div=0.0632, reconstruction_loss=0.248, total_loss=0.312]
# Z_DIM = 6 | Epoch 21/50: 100%|██████████| 42/42 [00:00<00:00, 121.41it/s, kl_div=0.0623, reconstruction_loss=0.256, total_loss=0.318]
# Z_DIM = 6 | Epoch 22/50: 100%|██████████| 42/42 [00:00<00:00, 140.94it/s, kl_div=0.0614, reconstruction_loss=0.252, total_loss=0.313]
# Z_DIM = 6 | Epoch 23/50: 100%|██████████| 42/42 [00:00<00:00, 145.67it/s, kl_div=0.0607, reconstruction_loss=0.251, total_loss=0.311]
# Z_DIM = 6 | Epoch 24/50: 100%|██████████| 42/42 [00:00<00:00, 151.09it/s, kl_div=0.061, reconstruction_loss=0.248, total_loss=0.309]
# Z_DIM = 6 | Epoch 25/50: 100%|██████████| 42/42 [00:00<00:00, 149.89it/s, kl_div=0.0611, reconstruction_loss=0.245, total_loss=0.306]
# Z_DIM = 6 | Epoch 26/50: 100%|██████████| 42/42 [00:00<00:00, 145.84it/s, kl_div=0.0607, reconstruction_loss=0.263, total_loss=0.324]
# Z_DIM = 6 | Epoch 27/50: 100%|██████████| 42/42 [00:00<00:00, 125.58it/s, kl_div=0.0601, reconstruction_loss=0.253, total_loss=0.313]
# Z_DIM = 6 | Epoch 28/50: 100%|██████████| 42/42 [00:00<00:00, 128.60it/s, kl_div=0.06, reconstruction_loss=0.248, total_loss=0.308]
# Z_DIM = 6 | Epoch 29/50: 100%|██████████| 42/42 [00:00<00:00, 129.70it/s, kl_div=0.0605, reconstruction_loss=0.244, total_loss=0.305]
# Z_DIM = 6 | Epoch 30/50: 100%|██████████| 42/42 [00:00<00:00, 115.70it/s, kl_div=0.0605, reconstruction_loss=0.242, total_loss=0.302]
# Z_DIM = 6 | Epoch 31/50: 100%|██████████| 42/42 [00:00<00:00, 139.60it/s, kl_div=0.0605, reconstruction_loss=0.245, total_loss=0.306]
# Z_DIM = 6 | Epoch 32/50: 100%|██████████| 42/42 [00:00<00:00, 155.75it/s, kl_div=0.0602, reconstruction_loss=0.241, total_loss=0.301]
# Z_DIM = 6 | Epoch 33/50: 100%|██████████| 42/42 [00:00<00:00, 159.90it/s, kl_div=0.0601, reconstruction_loss=0.251, total_loss=0.311]
# Z_DIM = 6 | Epoch 34/50: 100%|██████████| 42/42 [00:00<00:00, 128.89it/s, kl_div=0.0607, reconstruction_loss=0.234, total_loss=0.295]
# Z_DIM = 6 | Epoch 35/50: 100%|██████████| 42/42 [00:00<00:00, 172.84it/s, kl_div=0.0598, reconstruction_loss=0.238, total_loss=0.298]
# Z_DIM = 6 | Epoch 36/50: 100%|██████████| 42/42 [00:00<00:00, 168.07it/s, kl_div=0.0599, reconstruction_loss=0.247, total_loss=0.307]
# Z_DIM = 6 | Epoch 37/50: 100%|██████████| 42/42 [00:00<00:00, 152.08it/s, kl_div=0.0591, reconstruction_loss=0.236, total_loss=0.295]
# Z_DIM = 6 | Epoch 38/50: 100%|██████████| 42/42 [00:00<00:00, 131.69it/s, kl_div=0.0588, reconstruction_loss=0.237, total_loss=0.296]
# Z_DIM = 6 | Epoch 39/50: 100%|██████████| 42/42 [00:00<00:00, 128.35it/s, kl_div=0.0588, reconstruction_loss=0.238, total_loss=0.296]
# Z_DIM = 6 | Epoch 40/50: 100%|██████████| 42/42 [00:00<00:00, 125.18it/s, kl_div=0.0589, reconstruction_loss=0.233, total_loss=0.292]
# Z_DIM = 6 | Epoch 41/50: 100%|██████████| 42/42 [00:00<00:00, 124.17it/s, kl_div=0.0588, reconstruction_loss=0.239, total_loss=0.297]
# Z_DIM = 6 | Epoch 42/50: 100%|██████████| 42/42 [00:00<00:00, 122.38it/s, kl_div=0.059, reconstruction_loss=0.23, total_loss=0.289]
# Z_DIM = 6 | Epoch 43/50: 100%|██████████| 42/42 [00:00<00:00, 151.30it/s, kl_div=0.0595, reconstruction_loss=0.231, total_loss=0.29]
# ...
# Z_DIM = 10 | Epoch 19/50: 100%|██████████| 42/42 [00:00<00:00, 126.68it/s, kl_div=0.064, reconstruction_loss=0.262, total_loss=0.326]
# Z_DIM = 10 | Epoch 20/50: 100%|██████████| 42/42 [00:00<00:00, 145.58it/s, kl_div=0.0568, reconstruction_loss=0.259, total_loss=0.316]
# Z_DIM = 10 | Epoch 21/50: 100%|██████████| 42/42 [00:00<00:00, 163.79it/s, kl_div=0.0641, reconstruction_loss=0.252, total_loss=0.316]
# Z_DIM = 10 | Epoch 22/50: 100%|██████████| 42/42 [00:00<00:00, 129.70it/s, kl_div=0.0602, reconstruction_loss=0.259, total_loss=0.319]
# Z_DIM = 10 | Epoch 23/50: 100%|██████████| 42/42 [00:00<00:00, 128.14it/s, kl_div=0.0563, reconstruction_loss=0.257, total_loss=0.313]
# Z_DIM = 10 | Epoch 24/50: 100%|██████████| 42/42 [00:00<00:00, 140.54it/s, kl_div=0.0626, reconstruction_loss=0.254, total_loss=0.316]
# Z_DIM = 10 | Epoch 25/50: 100%|██████████| 42/42 [00:00<00:00, 126.96it/s, kl_div=0.0612, reconstruction_loss=0.25, total_loss=0.312]
# Z_DIM = 10 | Epoch 26/50: 100%|██████████| 42/42 [00:00<00:00, 143.07it/s, kl_div=0.0577, reconstruction_loss=0.256, total_loss=0.314]
# Z_DIM = 10 | Epoch 27/50: 100%|██████████| 42/42 [00:00<00:00, 146.96it/s, kl_div=0.0583, reconstruction_loss=0.253, total_loss=0.311]
# Z_DIM = 10 | Epoch 28/50: 100%|██████████| 42/42 [00:00<00:00, 142.80it/s, kl_div=0.0551, reconstruction_loss=0.246, total_loss=0.301]
# Z_DIM = 10 | Epoch 29/50: 100%|██████████| 42/42 [00:00<00:00, 145.53it/s, kl_div=0.0512, reconstruction_loss=0.248, total_loss=0.299]
# Z_DIM = 10 | Epoch 30/50: 100%|██████████| 42/42 [00:00<00:00, 159.49it/s, kl_div=0.0507, reconstruction_loss=0.257, total_loss=0.308]
# Z_DIM = 10 | Epoch 31/50: 100%|██████████| 42/42 [00:00<00:00, 165.88it/s, kl_div=0.051, reconstruction_loss=0.25, total_loss=0.301]
# Z_DIM = 10 | Epoch 32/50: 100%|██████████| 42/42 [00:00<00:00, 156.05it/s, kl_div=0.0556, reconstruction_loss=0.25, total_loss=0.305]
# Z_DIM = 10 | Epoch 33/50: 100%|██████████| 42/42 [00:00<00:00, 153.44it/s, kl_div=0.0548, reconstruction_loss=0.252, total_loss=0.307]
# Z_DIM = 10 | Epoch 34/50: 100%|██████████| 42/42 [00:00<00:00, 130.70it/s, kl_div=0.0531, reconstruction_loss=0.248, total_loss=0.301]
# Z_DIM = 10 | Epoch 35/50: 100%|██████████| 42/42 [00:00<00:00, 150.74it/s, kl_div=0.0572, reconstruction_loss=0.249, total_loss=0.306]
# Z_DIM = 10 | Epoch 36/50: 100%|██████████| 42/42 [00:00<00:00, 120.14it/s, kl_div=0.0542, reconstruction_loss=0.245, total_loss=0.299]
# Z_DIM = 10 | Epoch 37/50: 100%|██████████| 42/42 [00:00<00:00, 128.77it/s, kl_div=0.0522, reconstruction_loss=0.253, total_loss=0.305]
# Z_DIM = 10 | Epoch 38/50: 100%|██████████| 42/42 [00:00<00:00, 114.52it/s, kl_div=0.0505, reconstruction_loss=0.249, total_loss=0.3]
# Z_DIM = 10 | Epoch 39/50: 100%|██████████| 42/42 [00:00<00:00, 137.66it/s, kl_div=0.054, reconstruction_loss=0.251, total_loss=0.305]
# Z_DIM = 10 | Epoch 40/50: 100%|██████████| 42/42 [00:00<00:00, 160.04it/s, kl_div=0.0544, reconstruction_loss=0.256, total_loss=0.31]
# Z_DIM = 10 | Epoch 41/50: 100%|██████████| 42/42 [00:00<00:00, 140.49it/s, kl_div=0.0528, reconstruction_loss=0.255, total_loss=0.307]
# Z_DIM = 10 | Epoch 42/50: 100%|██████████| 42/42 [00:00<00:00, 148.26it/s, kl_div=0.0518, reconstruction_loss=0.252, total_loss=0.304]
# Z_DIM = 10 | Epoch 43/50: 100%|██████████| 42/42 [00:00<00:00, 141.30it/s, kl_div=0.0563, reconstruction_loss=0.248, total_loss=0.304]
# Z_DIM = 10 | Epoch 44/50: 100%|██████████| 42/42 [00:00<00:00, 140.46it/s, kl_div=0.0536, reconstruction_loss=0.251, total_loss=0.305]
# Z_DIM = 10 | Epoch 45/50: 100%|██████████| 42/42 [00:00<00:00, 137.11it/s, kl_div=0.0521, reconstruction_loss=0.248, total_loss=0.3]
# Z_DIM = 10 | Epoch 46/50: 100%|██████████| 42/42 [00:00<00:00, 122.61it/s, kl_div=0.0506, reconstruction_loss=0.248, total_loss=0.299]
# Z_DIM = 10 | Epoch 47/50: 100%|██████████| 42/42 [00:00<00:00, 136.12it/s, kl_div=0.0559, reconstruction_loss=0.248, total_loss=0.303]
# Z_DIM = 10 | Epoch 48/50: 100%|██████████| 42/42 [00:00<00:00, 149.82it/s, kl_div=0.0552, reconstruction_loss=0.246, total_loss=0.301]
# Z_DIM = 10 | Epoch 49/50: 100%|██████████| 42/42 [00:00<00:00, 132.14it/s, kl_div=0.0618, reconstruction_loss=0.242, total_loss=0.304]
# Z_DIM = 10 | Epoch 50/50: 100%|██████████| 42/42 [00:00<00:00, 138.72it/s, kl_div=0.058, reconstruction_loss=0.244, total_loss=0.302]
# Z_DIM = 10 | Epoch 1/50: 100%|██████████| 42/42 [00:00<00:00, 151.96it/s, kl_div=0.0773, reconstruction_loss=0.259, total_loss=0.336]
# Z_DIM = 10 | Epoch 2/50: 100%|██████████| 42/42 [00:00<00:00, 154.28it/s, kl_div=0.0861, reconstruction_loss=0.236, total_loss=0.322]
# Z_DIM = 10 | Epoch 3/50: 100%|██████████| 42/42 [00:00<00:00, 145.69it/s, kl_div=0.0761, reconstruction_loss=0.231, total_loss=0.307]
# Z_DIM = 10 | Epoch 4/50: 100%|██████████| 42/42 [00:00<00:00, 163.99it/s, kl_div=0.0776, reconstruction_loss=0.224, total_loss=0.302]
# Z_DIM = 10 | Epoch 5/50: 100%|██████████| 42/42 [00:00<00:00, 154.01it/s, kl_div=0.0683, reconstruction_loss=0.214, total_loss=0.282]
# Z_DIM = 10 | Epoch 6/50: 100%|██████████| 42/42 [00:00<00:00, 139.83it/s, kl_div=0.0701, reconstruction_loss=0.209, total_loss=0.279]
# Z_DIM = 10 | Epoch 7/50: 100%|██████████| 42/42 [00:00<00:00, 139.99it/s, kl_div=0.0671, reconstruction_loss=0.199, total_loss=0.266]
# Z_DIM = 10 | Epoch 8/50: 100%|██████████| 42/42 [00:00<00:00, 148.06it/s, kl_div=0.0678, reconstruction_loss=0.204, total_loss=0.272]
# Z_DIM = 10 | Epoch 9/50: 100%|██████████| 42/42 [00:00<00:00, 134.33it/s, kl_div=0.0702, reconstruction_loss=0.2, total_loss=0.27]
# Z_DIM = 10 | Epoch 10/50: 100%|██████████| 42/42 [00:00<00:00, 145.95it/s, kl_div=0.0626, reconstruction_loss=0.199, total_loss=0.262]
# Z_DIM = 10 | Epoch 11/50: 100%|██████████| 42/42 [00:00<00:00, 154.68it/s, kl_div=0.0584, reconstruction_loss=0.204, total_loss=0.262]
# Z_DIM = 10 | Epoch 12/50: 100%|██████████| 42/42 [00:00<00:00, 149.91it/s, kl_div=0.0625, reconstruction_loss=0.197, total_loss=0.26]
# Z_DIM = 10 | Epoch 13/50: 100%|██████████| 42/42 [00:00<00:00, 136.84it/s, kl_div=0.062, reconstruction_loss=0.202, total_loss=0.264]
# Z_DIM = 10 | Epoch 14/50: 100%|██████████| 42/42 [00:00<00:00, 153.71it/s, kl_div=0.0595, reconstruction_loss=0.194, total_loss=0.253]
# Z_DIM = 10 | Epoch 15/50: 100%|██████████| 42/42 [00:00<00:00, 149.25it/s, kl_div=0.0558, reconstruction_loss=0.193, total_loss=0.249]
# Z_DIM = 10 | Epoch 16/50: 100%|██████████| 42/42 [00:00<00:00, 145.32it/s, kl_div=0.057, reconstruction_loss=0.196, total_loss=0.253]
# Z_DIM = 10 | Epoch 17/50: 100%|██████████| 42/42 [00:00<00:00, 157.52it/s, kl_div=0.0564, reconstruction_loss=0.19, total_loss=0.246]
# Z_DIM = 10 | Epoch 18/50: 100%|██████████| 42/42 [00:00<00:00, 156.69it/s, kl_div=0.0535, reconstruction_loss=0.188, total_loss=0.241]
# Z_DIM = 10 | Epoch 19/50: 100%|██████████| 42/42 [00:00<00:00, 158.26it/s, kl_div=0.0555, reconstruction_loss=0.195, total_loss=0.251]
# Z_DIM = 10 | Epoch 20/50: 100%|██████████| 42/42 [00:00<00:00, 132.63it/s, kl_div=0.0526, reconstruction_loss=0.19, total_loss=0.243]
# Z_DIM = 10 | Epoch 21/50: 100%|██████████| 42/42 [00:00<00:00, 142.35it/s, kl_div=0.0527, reconstruction_loss=0.191, total_loss=0.244]
# Z_DIM = 10 | Epoch 22/50: 100%|██████████| 42/42 [00:00<00:00, 147.14it/s, kl_div=0.0534, reconstruction_loss=0.191, total_loss=0.244]
# Z_DIM = 10 | Epoch 23/50: 100%|██████████| 42/42 [00:00<00:00, 151.30it/s, kl_div=0.0509, reconstruction_loss=0.191, total_loss=0.242]
# Z_DIM = 10 | Epoch 24/50: 100%|██████████| 42/42 [00:00<00:00, 140.22it/s, kl_div=0.0529, reconstruction_loss=0.188, total_loss=0.241]
# Z_DIM = 10 | Epoch 25/50: 100%|██████████| 42/42 [00:00<00:00, 170.69it/s, kl_div=0.0531, reconstruction_loss=0.186, total_loss=0.239]
# Z_DIM = 10 | Epoch 26/50: 100%|██████████| 42/42 [00:00<00:00, 161.85it/s, kl_div=0.0516, reconstruction_loss=0.186, total_loss=0.238]
# Z_DIM = 10 | Epoch 27/50: 100%|██████████| 42/42 [00:00<00:00, 141.99it/s, kl_div=0.0522, reconstruction_loss=0.188, total_loss=0.24]
# Z_DIM = 10 | Epoch 28/50: 100%|██████████| 42/42 [00:00<00:00, 115.85it/s, kl_div=0.0512, reconstruction_loss=0.183, total_loss=0.235]
# Z_DIM = 10 | Epoch 29/50: 100%|██████████| 42/42 [00:00<00:00, 125.76it/s, kl_div=0.051, reconstruction_loss=0.186, total_loss=0.237]
# Z_DIM = 10 | Epoch 30/50: 100%|██████████| 42/42 [00:00<00:00, 142.65it/s, kl_div=0.05, reconstruction_loss=0.189, total_loss=0.239]
# Z_DIM = 10 | Epoch 31/50: 100%|██████████| 42/42 [00:00<00:00, 145.72it/s, kl_div=0.052, reconstruction_loss=0.19, total_loss=0.242]
# Z_DIM = 10 | Epoch 32/50: 100%|██████████| 42/42 [00:00<00:00, 138.32it/s, kl_div=0.0501, reconstruction_loss=0.187, total_loss=0.237]
# Z_DIM = 10 | Epoch 33/50: 100%|██████████| 42/42 [00:00<00:00, 154.11it/s, kl_div=0.0487, reconstruction_loss=0.192, total_loss=0.24]
# Z_DIM = 10 | Epoch 34/50: 100%|██████████| 42/42 [00:00<00:00, 132.54it/s, kl_div=0.0501, reconstruction_loss=0.186, total_loss=0.236]
# Z_DIM = 10 | Epoch 35/50: 100%|██████████| 42/42 [00:00<00:00, 131.63it/s, kl_div=0.0508, reconstruction_loss=0.183, total_loss=0.234]
# Z_DIM = 10 | Epoch 36/50: 100%|██████████| 42/42 [00:00<00:00, 172.91it/s, kl_div=0.0501, reconstruction_loss=0.189, total_loss=0.239]
# Z_DIM = 10 | Epoch 37/50:  14%|█▍        | 6/42 [00:00<00:00, 154.82it/s, kl_div=0.0746, reconstruction_loss=0.203, total_loss=0.278]
# [W 2025-05-22 10:08:56,528] Trial 3 failed with parameters: {'h_dim1': 88, 'h_dim2': 72, 'z_dim': 10, 'lr': 0.003285865660269766, 'batch_size': 32, 'activation': 'relu'} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "<ipython-input-10-fbaa82e41e1b>", line 38, in objective
#     history = train_one_fold(model, train_loader, val_loader, optimizer, loss_fn, DEVICE, num_epochs=50, z_dim=z_dim)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<ipython-input-9-9e3f631cc517>", line 35, in train_one_fold
#     optimizer.step()
#   File "/usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py", line 493, in wrapper
#     out = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py", line 91, in _use_grad
#     ret = func(self, *args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/optim/adam.py", line 244, in step
#     adam(
#   File "/usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py", line 154, in maybe_fallback
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/optim/adam.py", line 876, in adam
#     func(
#   File "/usr/local/lib/python3.11/dist-packages/torch/optim/adam.py", line 425, in _single_tensor_adam
#     exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     ^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [W 2025-05-22 10:08:56,533] Trial 3 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-66bdb47d900f> in <cell line: 0>()
#       3     pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10))
#       4
# ----> 5 study.optimize(functools.partial(objective, train_tensor=train_tensor, INPUT_DIM=INPUT_DIM), n_trials=50, catch=(Exception,))
#
# /usr/local/lib/python3.11/dist-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     473                 If nested invocation of this method occurs.
#     474         """
# --> 475         _optimize(
#     476             study=self,
#     477             func=func,
#
# /usr/local/lib/python3.11/dist-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61     try:
#      62         if n_jobs == 1:
# ---> 63             _optimize_sequential(
#      64                 study,
#      65                 func,
#
# /usr/local/lib/python3.11/dist-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     158
#     159         try:
# --> 160             frozen_trial = _run_trial(study, func, catch)
#     161         finally:
#     162             # The following line mitigates memory problems that can be occurred in some
#
# /usr/local/lib/python3.11/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     246         and not isinstance(func_err, catch)
#     247     ):
# --> 248         raise func_err
#     249     return frozen_trial
#     250
#
# /usr/local/lib/python3.11/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     195     with get_heartbeat_thread(trial._trial_id, study._storage):
#     196         try:
# --> 197             value_or_values = func(trial)
#     198         except exceptions.TrialPruned as e:
#     199             # TODO(mamu): Handle multi-objective cases.
#
# <ipython-input-10-fbaa82e41e1b> in objective(trial, train_tensor, INPUT_DIM)
#      36     loss_fn = nn.MSELoss(reduction="sum")
#      37
# ---> 38     history = train_one_fold(model, train_loader, val_loader, optimizer, loss_fn, DEVICE, num_epochs=50, z_dim=z_dim)
#      39
#      40     val_losses.append(history['val_total_loss'][-1])
#
# <ipython-input-9-9e3f631cc517> in train_one_fold(model, train_loader, val_loader, optimizer, loss_fn, device, num_epochs, z_dim)
#      33       optimizer.zero_grad()
#      34       loss.backward()
# ---> 35       optimizer.step()
#      36
#      37       loop.set_postfix(                                               # sto decidendo che info printare nella barra che vedo ad ogni epoca
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     491                             )
#     492
# --> 493                 out = func(*args, **kwargs)
#     494                 self._optimizer_step_code()
#     495
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      89             torch.set_grad_enabled(self.defaults["differentiable"])
#      90             torch._dynamo.graph_break()
# ---> 91             ret = func(self, *args, **kwargs)
#      92         finally:
#      93             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/adam.py in step(self, closure)
#     242             )
#     243
# --> 244             adam(
#     245                 params_with_grad,
#     246                 grads,
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in maybe_fallback(*args, **kwargs)
#     152                 return disabled_func(*args, **kwargs)
#     153             else:
# --> 154                 return func(*args, **kwargs)
#     155
#     156         return maybe_fallback
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     874         func = _single_tensor_adam
#     875
# --> 876     func(
#     877         params,
#     878         grads,
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/adam.py in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     423         exp_avg.lerp_(grad, 1 - device_beta1)
#     424
# --> 425         exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     426
#     427         if capturable or differentiable:
#
# KeyboardInterrupt:

# %%
best_params = study.best_trial.params

activation_fn = {"relu": nn.ReLU(), "sigmoid": nn.Sigmoid(), "leaky_relu": nn.LeakyReLU()}[best_params['activation']]
print("Best hyperparameters found:")
for k, v in best_params.items():
    print(f"  {k}: {v}")

# %% [markdown]
# Usando i best parameters uso tutto il training set

# %%
# Rebuild model using best parameters
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_model = VariationalAutoEncoder(INPUT_DIM,
                                    best_params['h_dim1'],
                                    best_params['h_dim2'],
                                    best_params['z_dim'],
                                    best_params['batch_size'],
                                    activation_fn=activation_fn
                                    ).to(DEVICE)
optimizer = torch.optim.Adam(best_model.parameters(), lr=best_params['lr'])
loss_fn = nn.MSELoss(reduction="sum")

# Use entire training dataset
train_loader = DataLoader(TabularDataset(train_tensor), batch_size=best_params['batch_size'], shuffle=False)
test_loader = DataLoader(TabularDataset(test_tensor), batch_size=best_params['batch_size'], shuffle=False)

# Train final model (increase epochs if needed)
_ = train_one_fold(best_model, train_loader, test_loader, optimizer, loss_fn, DEVICE, num_epochs=100, z_dim=best_params['z_dim'])       # setta qui le epoche

# %%
torch.save(best_model.state_dict(), f"vae_best_model_weights.pt")

with open("vae_best_model.json", "w") as f:
  json.dump(best_params, f)
